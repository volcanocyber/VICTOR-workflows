# %% [markdown]
# ### Bend Benchmark
#
# This benchmark simulates a sharp bend in the channel of a flow

# %%
import rioxarray as rxr
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.insert(0,"/home/jovyan/shared/Libraries")
import victor
import cartopy.crs as ccrs
import subprocess
import os
import pandas as pd
import xarray as xr
import rasterio as rio
import h5py
from scipy.interpolate import griddata
from rasterio.enums import Resampling
from rasterio.warp import transform_bounds

# %% [markdown]
# ### To choose between levels of flux, please specify

# %%
easting = 550
northing = 500
dem = "DEMs_PDC_Benchmark/bend_arc.asc"
raster = rxr.open_rasterio(dem)
raster = raster.sel({"band": 1})
xll, yll = float(raster.x.min()), float(raster.y.min())
coordinates = np.array([int(easting),int(northing)])
res = raster.rio.resolution()[0]

# %% [markdown]
# ## Volcflow
#
# ### An open source varient running on Octave

# %%
os.chdir("VolcFlow")
f = open("toposcript_merapi.m","r+")
inp = f.readlines()
inp[0] = f"fid = fopen('../DEMs_PDC_Benchmark/bend_arc.grd');\n"
inp[26] = f"dtplot = 1;\n"
inp[27] = f"tmax = 100;\n"
inp[42] = f"V={1e6};\n"
inp[44] = f"r=5;\n"
inp[48] = f"jh=110; ih=100;\n"
f.seek(0)
f.writelines(inp)
f.truncate()
f.close()

g = open("output_script.m","r+")
inp = g.readlines()
inp[0] = "fid = fopen('../DEMs_PDC_Benchmark/bend_arc.grd');\n"
inp[15] = "out=fopen('bend_output.grd','wb');\n"
g.seek(0)
g.writelines(inp)
g.truncate()
g.close()

subprocess.run("octave script_VF_merapi.m",shell=True,stderr=subprocess.DEVNULL)

os.chdir("..")
# Out:
#      ___________  Version n� 4.0.0   ___________
#      |                                                 |
#      | VolcFlow is a numerical code for the simulation |
#      |  of geophysical flows on complex topographies.  |
#      |          It is written by Karim Kelfoun,        |
#      |      Laboratoire Magmas et Volcans, UMR 6524    |
#      |           Clermont-Auvergne University          |
#      |      6, avenue Blaise Pascal, 63170 Aubi�re     |
#      |           <a href = "http://https://lmv.uca.fr/volcflow/">Visit the VolcFlow web site.</a>          |
#      |                                                 |
#      |   ---       License : Karim Kelfoun       ---   |
#      ���������������������������������������������������
# ans = 0
# The center of mass is located in i=NaN, j=NaN (in meshes).
# Warning ! With a variable time step, dt should be defined so that: dt�2^n = dtplot ! Corrected value: dt = 0.125000 !
#
#
# VolcFlow is now running...
# time :    0.000 s., dt =     0.13 s., v max =  m/s (h>0.000 m), volume =     0.00 m3
# time :    0.125 s., dt =     0.13 s., v max =     0.00 m/s (h>0.000 m), volume =  2083.33 m3
# time :    0.250 s., dt =     0.13 s., v max =     0.13 m/s (h>0.000 m), volume =  4166.67 m3
# time :    0.375 s., dt =     0.13 s., v max =     0.61 m/s (h>0.000 m), volume =  6250.00 m3
# time :    0.500 s., dt =     0.13 s., v max =     1.10 m/s (h>0.000 m), volume =  8333.33 m3
# time :    0.625 s., dt =     0.13 s., v max =     1.72 m/s (h>0.000 m), volume = 10416.67 m3
# time :    0.750 s., dt =     0.13 s., v max =     2.36 m/s (h>0.000 m), volume = 12500.00 m3
# time :    0.875 s., dt =     0.13 s., v max =     2.99 m/s (h>0.000 m), volume = 14583.33 m3
#
# Draw at 1.000000 s (1.0%), estimated duration : 238.28s .
# time :    1.000 s., dt =     0.25 s., v max =     3.64 m/s (h>0.000 m), volume = 16666.67 m3
# time :    1.250 s., dt =     0.25 s., v max =     5.64 m/s (h>0.000 m), volume = 20833.33 m3
# time :    1.500 s., dt =     0.25 s., v max =     7.32 m/s (h>0.000 m), volume = 25000.00 m3
# time :    1.750 s., dt =     0.25 s., v max =     9.11 m/s (h>0.000 m), volume = 29166.67 m3
#
# Draw at 2.000000 s (2.0%), estimated duration : 171.52s .
# time :    2.000 s., dt =     0.25 s., v max =    10.79 m/s (h>0.000 m), volume = 33333.33 m3
# time :    2.250 s., dt =     0.25 s., v max =    12.08 m/s (h>0.000 m), volume = 37500.00 m3
# time :    2.500 s., dt =     0.25 s., v max =    13.58 m/s (h>0.000 m), volume = 41666.67 m3
# time :    2.500 s., dt =     0.13 s., v max =    14.81 m/s (h>0.000 m), volume = 41666.67 m3
# time :    2.625 s., dt =     0.13 s., v max =    13.94 m/s (h>0.000 m), volume = 43750.00 m3
# time :    2.750 s., dt =     0.13 s., v max =    14.50 m/s (h>0.000 m), volume = 45833.33 m3
# time :    2.875 s., dt =     0.13 s., v max =    14.88 m/s (h>0.000 m), volume = 47916.66 m3
#
# Draw at 3.000000 s (3.0%), estimated duration : 173.99s .
# time :    3.000 s., dt =     0.25 s., v max =    15.38 m/s (h>0.000 m), volume = 50000.00 m3
# time :    3.000 s., dt =     0.13 s., v max =    16.46 m/s (h>0.000 m), volume = 50000.00 m3
# time :    3.125 s., dt =     0.13 s., v max =    15.82 m/s (h>0.000 m), volume = 52083.33 m3
# time :    3.250 s., dt =     0.13 s., v max =    16.22 m/s (h>0.000 m), volume = 54166.66 m3
# time :    3.375 s., dt =     0.13 s., v max =    16.61 m/s (h>0.000 m), volume = 56249.99 m3
# time :    3.500 s., dt =     0.13 s., v max =    17.02 m/s (h>0.000 m), volume = 58333.33 m3
# time :    3.625 s., dt =     0.13 s., v max =    17.44 m/s (h>0.000 m), volume = 60416.66 m3
# time :    3.750 s., dt =     0.13 s., v max =    17.92 m/s (h>0.000 m), volume = 62499.99 m3
# time :    3.875 s., dt =     0.13 s., v max =    18.39 m/s (h>0.000 m), volume = 64583.33 m3
#
# Draw at 4.000000 s (4.0%), estimated duration : 187.73s .
# time :    4.000 s., dt =     0.13 s., v max =    18.84 m/s (h>0.000 m), volume = 66666.66 m3
# time :    4.125 s., dt =     0.13 s., v max =    19.24 m/s (h>0.000 m), volume = 68749.99 m3
# time :    4.250 s., dt =     0.13 s., v max =    19.59 m/s (h>0.000 m), volume = 70833.32 m3
# time :    4.375 s., dt =     0.13 s., v max =    20.00 m/s (h>0.000 m), volume = 72916.66 m3
# time :    4.500 s., dt =     0.13 s., v max =    20.37 m/s (h>0.000 m), volume = 74999.99 m3
# time :    4.625 s., dt =     0.13 s., v max =    20.69 m/s (h>0.000 m), volume = 77083.32 m3
# time :    4.750 s., dt =     0.13 s., v max =    20.99 m/s (h>0.000 m), volume = 79166.66 m3
# time :    4.875 s., dt =     0.13 s., v max =    21.29 m/s (h>0.000 m), volume = 81249.99 m3
#
# Draw at 5.000000 s (5.0%), estimated duration : 189.64s .
# time :    5.000 s., dt =     0.13 s., v max =    21.60 m/s (h>0.000 m), volume = 83333.32 m3
# time :    5.125 s., dt =     0.13 s., v max =    21.85 m/s (h>0.000 m), volume = 85416.66 m3
# time :    5.250 s., dt =     0.13 s., v max =    22.07 m/s (h>0.000 m), volume = 87499.99 m3
# time :    5.375 s., dt =     0.13 s., v max =    22.29 m/s (h>0.000 m), volume = 89583.32 m3
# time :    5.500 s., dt =     0.13 s., v max =    22.52 m/s (h>0.000 m), volume = 91666.66 m3
# time :    5.625 s., dt =     0.13 s., v max =    22.71 m/s (h>0.000 m), volume = 93749.99 m3
# time :    5.750 s., dt =     0.13 s., v max =    22.86 m/s (h>0.000 m), volume = 95833.32 m3
# time :    5.875 s., dt =     0.13 s., v max =    23.02 m/s (h>0.000 m), volume = 97916.65 m3
#
# Draw at 6.000000 s (6.0%), estimated duration : 190.49s .
# time :    6.000 s., dt =     0.13 s., v max =    23.19 m/s (h>0.000 m), volume = 99999.98 m3
# time :    6.125 s., dt =     0.13 s., v max =    23.33 m/s (h>0.000 m), volume = 102083.31 m3
# time :    6.250 s., dt =     0.13 s., v max =    23.44 m/s (h>0.000 m), volume = 104166.64 m3
# time :    6.375 s., dt =     0.13 s., v max =    23.55 m/s (h>0.000 m), volume = 106249.97 m3
# time :    6.500 s., dt =     0.13 s., v max =    23.67 m/s (h>0.000 m), volume = 108333.30 m3
# time :    6.625 s., dt =     0.13 s., v max =    23.76 m/s (h>0.000 m), volume = 110416.63 m3
# time :    6.750 s., dt =     0.13 s., v max =    23.84 m/s (h>0.000 m), volume = 112499.97 m3
# time :    6.875 s., dt =     0.13 s., v max =    23.91 m/s (h>0.000 m), volume = 114583.30 m3
#
# Draw at 7.000000 s (7.0%), estimated duration : 190.27s .
# time :    7.000 s., dt =     0.13 s., v max =    23.98 m/s (h>0.000 m), volume = 116666.63 m3
# time :    7.125 s., dt =     0.13 s., v max =    24.05 m/s (h>0.000 m), volume = 118749.97 m3
# time :    7.250 s., dt =     0.13 s., v max =    24.09 m/s (h>0.000 m), volume = 120833.30 m3
# time :    7.375 s., dt =     0.13 s., v max =    24.13 m/s (h>0.000 m), volume = 122916.63 m3
# time :    7.500 s., dt =     0.13 s., v max =    24.16 m/s (h>0.000 m), volume = 124999.96 m3
# time :    7.625 s., dt =     0.13 s., v max =    24.19 m/s (h>0.000 m), volume = 127083.30 m3
# time :    7.750 s., dt =     0.13 s., v max =    24.21 m/s (h>0.000 m), volume = 129166.63 m3
# time :    7.875 s., dt =     0.13 s., v max =    24.23 m/s (h>0.000 m), volume = 131249.96 m3
#
# Draw at 8.000000 s (8.0%), estimated duration : 189.55s .
# time :    8.000 s., dt =     0.13 s., v max =    24.24 m/s (h>0.000 m), volume = 133333.30 m3
# time :    8.125 s., dt =     0.13 s., v max =    24.25 m/s (h>0.000 m), volume = 135416.63 m3
# time :    8.250 s., dt =     0.13 s., v max =    24.25 m/s (h>0.000 m), volume = 137499.96 m3
# time :    8.375 s., dt =     0.13 s., v max =    24.25 m/s (h>0.000 m), volume = 139583.30 m3
# time :    8.500 s., dt =     0.13 s., v max =    24.25 m/s (h>0.000 m), volume = 141666.63 m3
# time :    8.625 s., dt =     0.13 s., v max =    24.25 m/s (h>0.000 m), volume = 143749.96 m3
# time :    8.750 s., dt =     0.13 s., v max =    24.25 m/s (h>0.000 m), volume = 145833.30 m3
# time :    8.875 s., dt =     0.13 s., v max =    24.24 m/s (h>0.000 m), volume = 147916.63 m3
#
# Draw at 9.000000 s (9.0%), estimated duration : 188.64s .
# time :    9.000 s., dt =     0.13 s., v max =    24.23 m/s (h>0.000 m), volume = 149999.96 m3
# time :    9.125 s., dt =     0.13 s., v max =    24.22 m/s (h>0.000 m), volume = 152083.30 m3
# time :    9.250 s., dt =     0.13 s., v max =    24.21 m/s (h>0.000 m), volume = 154166.63 m3
# time :    9.375 s., dt =     0.13 s., v max =    24.20 m/s (h>0.000 m), volume = 156249.96 m3
# time :    9.500 s., dt =     0.13 s., v max =    24.19 m/s (h>0.000 m), volume = 158333.29 m3
# time :    9.625 s., dt =     0.13 s., v max =    24.18 m/s (h>0.000 m), volume = 160416.62 m3
# time :    9.750 s., dt =     0.13 s., v max =    24.17 m/s (h>0.000 m), volume = 162499.96 m3
# time :    9.875 s., dt =     0.13 s., v max =    24.15 m/s (h>0.000 m), volume = 164583.29 m3
#
# Draw at 10.000000 s (10.0%), estimated duration : 189.06s .
# time :   10.000 s., dt =     0.13 s., v max =    24.15 m/s (h>0.000 m), volume = 166666.62 m3
# time :   10.125 s., dt =     0.13 s., v max =    24.22 m/s (h>0.000 m), volume = 168749.96 m3
# time :   10.250 s., dt =     0.13 s., v max =    24.43 m/s (h>0.000 m), volume = 170833.29 m3
# time :   10.375 s., dt =     0.13 s., v max =    24.63 m/s (h>0.000 m), volume = 172916.62 m3
# time :   10.500 s., dt =     0.13 s., v max =    24.85 m/s (h>0.000 m), volume = 174999.96 m3
# time :   10.625 s., dt =     0.13 s., v max =    25.06 m/s (h>0.000 m), volume = 177083.29 m3
# time :   10.750 s., dt =     0.13 s., v max =    25.30 m/s (h>0.000 m), volume = 179166.62 m3
# time :   10.875 s., dt =     0.13 s., v max =    25.51 m/s (h>0.000 m), volume = 181249.96 m3
#
# Draw at 11.000000 s (11.0%), estimated duration : 188.25s .
# time :   11.000 s., dt =     0.13 s., v max =    25.75 m/s (h>0.000 m), volume = 183333.29 m3
# time :   11.125 s., dt =     0.13 s., v max =    25.96 m/s (h>0.000 m), volume = 185416.62 m3
# time :   11.250 s., dt =     0.13 s., v max =    26.19 m/s (h>0.000 m), volume = 187499.95 m3
# time :   11.375 s., dt =     0.13 s., v max =    26.39 m/s (h>0.000 m), volume = 189583.29 m3
# time :   11.500 s., dt =     0.13 s., v max =    26.60 m/s (h>0.000 m), volume = 191666.62 m3
# time :   11.625 s., dt =     0.13 s., v max =    26.89 m/s (h>0.000 m), volume = 193749.95 m3
# time :   11.750 s., dt =     0.13 s., v max =    27.18 m/s (h>0.000 m), volume = 195833.28 m3
# time :   11.875 s., dt =     0.13 s., v max =    27.45 m/s (h>0.000 m), volume = 197916.62 m3
#
# Draw at 12.000000 s (12.0%), estimated duration : 187.86s .
# time :   12.000 s., dt =     0.13 s., v max =    27.71 m/s (h>0.000 m), volume = 199999.95 m3
# time :   12.125 s., dt =     0.13 s., v max =    27.93 m/s (h>0.000 m), volume = 202083.28 m3
# time :   12.250 s., dt =     0.13 s., v max =    28.16 m/s (h>0.000 m), volume = 204166.62 m3
# time :   12.250 s., dt =    0.063 s., v max =    28.36 m/s (h>0.000 m), volume = 204166.62 m3
# time :   12.313 s., dt =    0.063 s., v max =    28.24 m/s (h>0.000 m), volume = 205208.28 m3
# time :   12.375 s., dt =    0.063 s., v max =    28.32 m/s (h>0.000 m), volume = 206249.95 m3
# time :   12.438 s., dt =    0.063 s., v max =    28.39 m/s (h>0.000 m), volume = 207291.62 m3
# time :   12.500 s., dt =    0.063 s., v max =    28.46 m/s (h>0.000 m), volume = 208333.28 m3
# time :   12.563 s., dt =    0.063 s., v max =    28.57 m/s (h>0.000 m), volume = 209374.94 m3
# time :   12.625 s., dt =    0.063 s., v max =    28.69 m/s (h>0.000 m), volume = 210416.60 m3
# time :   12.688 s., dt =    0.063 s., v max =    28.79 m/s (h>0.000 m), volume = 211458.27 m3
# time :   12.750 s., dt =    0.063 s., v max =    28.91 m/s (h>0.000 m), volume = 212499.93 m3
# time :   12.813 s., dt =    0.063 s., v max =    29.02 m/s (h>0.000 m), volume = 213541.60 m3
# time :   12.875 s., dt =    0.063 s., v max =    29.12 m/s (h>0.000 m), volume = 214583.27 m3
# time :   12.938 s., dt =    0.063 s., v max =    29.21 m/s (h>0.000 m), volume = 215624.93 m3
#
# Draw at 13.000000 s (13.0%), estimated duration : 200.11s .
# time :   13.000 s., dt =     0.13 s., v max =    29.29 m/s (h>0.000 m), volume = 216666.60 m3
# time :   13.000 s., dt =    0.063 s., v max =    29.48 m/s (h>0.000 m), volume = 216666.60 m3
# time :   13.063 s., dt =    0.063 s., v max =    29.37 m/s (h>0.000 m), volume = 217708.26 m3
# time :   13.125 s., dt =    0.063 s., v max =    29.46 m/s (h>0.000 m), volume = 218749.93 m3
# time :   13.188 s., dt =    0.063 s., v max =    29.53 m/s (h>0.000 m), volume = 219791.60 m3
# time :   13.250 s., dt =    0.063 s., v max =    29.60 m/s (h>0.000 m), volume = 220833.26 m3
# time :   13.313 s., dt =    0.063 s., v max =    29.67 m/s (h>0.000 m), volume = 221874.93 m3
# time :   13.375 s., dt =    0.063 s., v max =    29.74 m/s (h>0.000 m), volume = 222916.59 m3
# time :   13.438 s., dt =    0.063 s., v max =    29.84 m/s (h>0.000 m), volume = 223958.26 m3
# time :   13.500 s., dt =    0.063 s., v max =    29.94 m/s (h>0.000 m), volume = 224999.93 m3
# time :   13.563 s., dt =    0.063 s., v max =    30.03 m/s (h>0.000 m), volume = 226041.59 m3
# time :   13.625 s., dt =    0.063 s., v max =    30.12 m/s (h>0.000 m), volume = 227083.26 m3
# time :   13.688 s., dt =    0.063 s., v max =    30.21 m/s (h>0.000 m), volume = 228124.93 m3
# time :   13.750 s., dt =    0.063 s., v max =    30.29 m/s (h>0.000 m), volume = 229166.59 m3
# time :   13.813 s., dt =    0.063 s., v max =    30.37 m/s (h>0.000 m), volume = 230208.26 m3
# time :   13.875 s., dt =    0.063 s., v max =    30.44 m/s (h>0.000 m), volume = 231249.92 m3
# time :   13.938 s., dt =    0.063 s., v max =    30.50 m/s (h>0.000 m), volume = 232291.59 m3
#
# Draw at 14.000000 s (14.0%), estimated duration : 212.84s .
# time :   14.000 s., dt =     0.13 s., v max =    30.56 m/s (h>0.000 m), volume = 233333.25 m3
# time :   14.000 s., dt =    0.063 s., v max =    30.69 m/s (h>0.000 m), volume = 233333.25 m3
# time :   14.063 s., dt =    0.063 s., v max =    30.62 m/s (h>0.000 m), volume = 234374.92 m3
# time :   14.125 s., dt =    0.063 s., v max =    30.67 m/s (h>0.000 m), volume = 235416.58 m3
# time :   14.188 s., dt =    0.063 s., v max =    30.73 m/s (h>0.000 m), volume = 236458.25 m3
# time :   14.250 s., dt =    0.063 s., v max =    30.82 m/s (h>0.000 m), volume = 237499.91 m3
# time :   14.313 s., dt =    0.063 s., v max =    30.90 m/s (h>0.000 m), volume = 238541.58 m3
# time :   14.375 s., dt =    0.063 s., v max =    30.97 m/s (h>0.000 m), volume = 239583.25 m3
# time :   14.438 s., dt =    0.063 s., v max =    31.04 m/s (h>0.000 m), volume = 240624.91 m3
# time :   14.500 s., dt =    0.063 s., v max =    31.11 m/s (h>0.000 m), volume = 241666.58 m3
# time :   14.563 s., dt =    0.063 s., v max =    31.17 m/s (h>0.000 m), volume = 242708.25 m3
# time :   14.625 s., dt =    0.063 s., v max =    31.22 m/s (h>0.000 m), volume = 243749.91 m3
# time :   14.688 s., dt =    0.063 s., v max =    31.27 m/s (h>0.000 m), volume = 244791.58 m3
# time :   14.750 s., dt =    0.063 s., v max =    31.32 m/s (h>0.000 m), volume = 245833.24 m3
# time :   14.813 s., dt =    0.063 s., v max =    31.36 m/s (h>0.000 m), volume = 246874.91 m3
# time :   14.875 s., dt =    0.063 s., v max =    31.40 m/s (h>0.000 m), volume = 247916.57 m3
# time :   14.938 s., dt =    0.063 s., v max =    31.45 m/s (h>0.000 m), volume = 248958.24 m3
#
# Draw at 15.000000 s (15.0%), estimated duration : 224.71s .
# time :   15.000 s., dt =     0.13 s., v max =    31.52 m/s (h>0.000 m), volume = 249999.91 m3
# time :   15.000 s., dt =    0.063 s., v max =    31.66 m/s (h>0.000 m), volume = 249999.91 m3
# time :   15.063 s., dt =    0.063 s., v max =    31.58 m/s (h>0.000 m), volume = 251041.57 m3
# time :   15.125 s., dt =    0.063 s., v max =    31.64 m/s (h>0.000 m), volume = 252083.24 m3
# time :   15.188 s., dt =    0.063 s., v max =    31.70 m/s (h>0.000 m), volume = 253124.91 m3
# time :   15.250 s., dt =    0.063 s., v max =    31.75 m/s (h>0.000 m), volume = 254166.57 m3
# time :   15.313 s., dt =    0.063 s., v max =    31.79 m/s (h>0.000 m), volume = 255208.24 m3
# time :   15.375 s., dt =    0.063 s., v max =    31.83 m/s (h>0.000 m), volume = 256249.90 m3
# time :   15.438 s., dt =    0.063 s., v max =    31.87 m/s (h>0.000 m), volume = 257291.57 m3
# time :   15.500 s., dt =    0.063 s., v max =    31.91 m/s (h>0.000 m), volume = 258333.24 m3
# time :   15.563 s., dt =    0.063 s., v max =    31.94 m/s (h>0.000 m), volume = 259374.90 m3
# time :   15.625 s., dt =    0.063 s., v max =    31.97 m/s (h>0.000 m), volume = 260416.57 m3
# time :   15.688 s., dt =    0.063 s., v max =    32.00 m/s (h>0.000 m), volume = 261458.24 m3
# time :   15.750 s., dt =    0.063 s., v max =    32.05 m/s (h>0.000 m), volume = 262499.90 m3
# time :   15.813 s., dt =    0.063 s., v max =    32.10 m/s (h>0.000 m), volume = 263541.57 m3
# time :   15.875 s., dt =    0.063 s., v max =    32.14 m/s (h>0.000 m), volume = 264583.23 m3
# time :   15.938 s., dt =    0.063 s., v max =    32.18 m/s (h>0.000 m), volume = 265624.90 m3
#
# Draw at 16.000000 s (16.0%), estimated duration : 233.31s .
# time :   16.000 s., dt =    0.063 s., v max =    32.22 m/s (h>0.000 m), volume = 266666.56 m3
# time :   16.063 s., dt =    0.063 s., v max =    32.26 m/s (h>0.000 m), volume = 267708.23 m3
# time :   16.125 s., dt =    0.063 s., v max =    32.29 m/s (h>0.000 m), volume = 268749.90 m3
# time :   16.188 s., dt =    0.063 s., v max =    32.32 m/s (h>0.000 m), volume = 269791.56 m3
# time :   16.250 s., dt =    0.063 s., v max =    32.34 m/s (h>0.000 m), volume = 270833.23 m3
# time :   16.313 s., dt =    0.063 s., v max =    32.37 m/s (h>0.000 m), volume = 271874.89 m3
# time :   16.375 s., dt =    0.063 s., v max =    32.39 m/s (h>0.000 m), volume = 272916.56 m3
# time :   16.438 s., dt =    0.063 s., v max =    32.41 m/s (h>0.000 m), volume = 273958.23 m3
# time :   16.500 s., dt =    0.063 s., v max =    32.43 m/s (h>0.000 m), volume = 274999.89 m3
# time :   16.563 s., dt =    0.063 s., v max =    32.46 m/s (h>0.000 m), volume = 276041.56 m3
# time :   16.625 s., dt =    0.063 s., v max =    32.49 m/s (h>0.000 m), volume = 277083.23 m3
# time :   16.688 s., dt =    0.063 s., v max =    32.52 m/s (h>0.000 m), volume = 278124.89 m3
# time :   16.750 s., dt =    0.063 s., v max =    32.55 m/s (h>0.000 m), volume = 279166.56 m3
# time :   16.813 s., dt =    0.063 s., v max =    32.58 m/s (h>0.000 m), volume = 280208.23 m3
# time :   16.875 s., dt =    0.063 s., v max =    32.60 m/s (h>0.000 m), volume = 281249.89 m3
# time :   16.938 s., dt =    0.063 s., v max =    32.63 m/s (h>0.000 m), volume = 282291.56 m3
#
# Draw at 17.000000 s (17.0%), estimated duration : 239.11s .
# time :   17.000 s., dt =    0.063 s., v max =    32.65 m/s (h>0.000 m), volume = 283333.22 m3
# time :   17.063 s., dt =    0.063 s., v max =    32.67 m/s (h>0.000 m), volume = 284374.89 m3
# time :   17.125 s., dt =    0.063 s., v max =    32.69 m/s (h>0.000 m), volume = 285416.56 m3
# time :   17.188 s., dt =    0.063 s., v max =    32.70 m/s (h>0.000 m), volume = 286458.22 m3
# time :   17.250 s., dt =    0.063 s., v max =    32.72 m/s (h>0.000 m), volume = 287499.89 m3
# time :   17.313 s., dt =    0.063 s., v max =    32.73 m/s (h>0.000 m), volume = 288541.56 m3
# time :   17.375 s., dt =    0.063 s., v max =    32.74 m/s (h>0.000 m), volume = 289583.22 m3
# time :   17.438 s., dt =    0.063 s., v max =    32.76 m/s (h>0.000 m), volume = 290624.89 m3
# time :   17.500 s., dt =    0.063 s., v max =    32.77 m/s (h>0.000 m), volume = 291666.55 m3
# time :   17.563 s., dt =    0.063 s., v max =    32.77 m/s (h>0.000 m), volume = 292708.22 m3
# time :   17.625 s., dt =    0.063 s., v max =    32.79 m/s (h>0.000 m), volume = 293749.88 m3
# time :   17.688 s., dt =    0.063 s., v max =    32.81 m/s (h>0.000 m), volume = 294791.55 m3
# time :   17.750 s., dt =    0.063 s., v max =    32.83 m/s (h>0.000 m), volume = 295833.21 m3
# time :   17.813 s., dt =    0.063 s., v max =    32.85 m/s (h>0.000 m), volume = 296874.88 m3
# time :   17.875 s., dt =    0.063 s., v max =    32.87 m/s (h>0.000 m), volume = 297916.55 m3
# time :   17.938 s., dt =    0.063 s., v max =    32.88 m/s (h>0.000 m), volume = 298958.21 m3
#
# Draw at 18.000000 s (18.0%), estimated duration : 242.95s .
# time :   18.000 s., dt =    0.063 s., v max =    32.90 m/s (h>0.000 m), volume = 299999.87 m3
# time :   18.063 s., dt =    0.063 s., v max =    32.91 m/s (h>0.000 m), volume = 301041.54 m3
# time :   18.125 s., dt =    0.063 s., v max =    32.92 m/s (h>0.000 m), volume = 302083.20 m3
# time :   18.188 s., dt =    0.063 s., v max =    32.94 m/s (h>0.000 m), volume = 303124.87 m3
# time :   18.250 s., dt =    0.063 s., v max =    32.95 m/s (h>0.000 m), volume = 304166.53 m3
# time :   18.313 s., dt =    0.063 s., v max =    32.96 m/s (h>0.000 m), volume = 305208.19 m3
# time :   18.375 s., dt =    0.063 s., v max =    32.97 m/s (h>0.000 m), volume = 306249.86 m3
# time :   18.438 s., dt =    0.063 s., v max =    32.98 m/s (h>0.000 m), volume = 307291.53 m3
# time :   18.500 s., dt =    0.063 s., v max =    32.98 m/s (h>0.000 m), volume = 308333.19 m3
# time :   18.563 s., dt =    0.063 s., v max =    32.99 m/s (h>0.000 m), volume = 309374.86 m3
# time :   18.625 s., dt =    0.063 s., v max =    33.00 m/s (h>0.000 m), volume = 310416.52 m3
# time :   18.688 s., dt =    0.063 s., v max =    33.01 m/s (h>0.000 m), volume = 311458.19 m3
# time :   18.750 s., dt =    0.063 s., v max =    33.01 m/s (h>0.000 m), volume = 312499.84 m3
# time :   18.813 s., dt =    0.063 s., v max =    33.02 m/s (h>0.000 m), volume = 313541.51 m3
# time :   18.875 s., dt =    0.063 s., v max =    33.04 m/s (h>0.000 m), volume = 314583.17 m3
# time :   18.938 s., dt =    0.063 s., v max =    33.06 m/s (h>0.000 m), volume = 315624.84 m3
#
# Draw at 19.000000 s (19.0%), estimated duration : 246.74s .
# time :   19.000 s., dt =    0.063 s., v max =    33.07 m/s (h>0.000 m), volume = 316666.50 m3
# time :   19.063 s., dt =    0.063 s., v max =    33.09 m/s (h>0.000 m), volume = 317708.16 m3
# time :   19.125 s., dt =    0.063 s., v max =    33.11 m/s (h>0.000 m), volume = 318749.83 m3
# time :   19.188 s., dt =    0.063 s., v max =    33.12 m/s (h>0.000 m), volume = 319791.49 m3
# time :   19.250 s., dt =    0.063 s., v max =    33.14 m/s (h>0.000 m), volume = 320833.16 m3
# time :   19.313 s., dt =    0.063 s., v max =    33.15 m/s (h>0.000 m), volume = 321874.82 m3
# time :   19.375 s., dt =    0.063 s., v max =    33.17 m/s (h>0.000 m), volume = 322916.48 m3
# time :   19.438 s., dt =    0.063 s., v max =    33.18 m/s (h>0.000 m), volume = 323958.15 m3
# time :   19.500 s., dt =    0.063 s., v max =    33.20 m/s (h>0.000 m), volume = 324999.82 m3
# time :   19.563 s., dt =    0.063 s., v max =    33.24 m/s (h>0.000 m), volume = 326041.48 m3
# time :   19.625 s., dt =    0.063 s., v max =    33.28 m/s (h>0.000 m), volume = 327083.15 m3
# time :   19.688 s., dt =    0.063 s., v max =    33.33 m/s (h>0.000 m), volume = 328124.81 m3
# time :   19.750 s., dt =    0.063 s., v max =    33.38 m/s (h>0.000 m), volume = 329166.48 m3
# time :   19.813 s., dt =    0.063 s., v max =    33.43 m/s (h>0.000 m), volume = 330208.14 m3
# time :   19.875 s., dt =    0.063 s., v max =    33.48 m/s (h>0.000 m), volume = 331249.81 m3
# time :   19.938 s., dt =    0.063 s., v max =    33.53 m/s (h>0.000 m), volume = 332291.48 m3
#
# Draw at 20.000000 s (20.0%), estimated duration : 249.62s .
# time :   20.000 s., dt =    0.063 s., v max =    33.59 m/s (h>0.000 m), volume = 333333.14 m3
# time :   20.063 s., dt =    0.063 s., v max =    33.65 m/s (h>0.000 m), volume = 334374.81 m3
# time :   20.125 s., dt =    0.063 s., v max =    33.71 m/s (h>0.000 m), volume = 335416.47 m3
# time :   20.188 s., dt =    0.063 s., v max =    33.77 m/s (h>0.000 m), volume = 336458.14 m3
# time :   20.250 s., dt =    0.063 s., v max =    33.84 m/s (h>0.000 m), volume = 337499.80 m3
# time :   20.313 s., dt =    0.063 s., v max =    33.90 m/s (h>0.000 m), volume = 338541.47 m3
# time :   20.375 s., dt =    0.063 s., v max =    33.97 m/s (h>0.000 m), volume = 339583.13 m3
# time :   20.438 s., dt =    0.063 s., v max =    34.03 m/s (h>0.000 m), volume = 340624.80 m3
# time :   20.500 s., dt =    0.063 s., v max =    34.10 m/s (h>0.000 m), volume = 341666.46 m3
# time :   20.563 s., dt =    0.063 s., v max =    34.16 m/s (h>0.000 m), volume = 342708.13 m3
# time :   20.625 s., dt =    0.063 s., v max =    34.23 m/s (h>0.000 m), volume = 343749.80 m3
# time :   20.688 s., dt =    0.063 s., v max =    34.30 m/s (h>0.000 m), volume = 344791.46 m3
# time :   20.750 s., dt =    0.063 s., v max =    34.36 m/s (h>0.000 m), volume = 345833.12 m3
# time :   20.813 s., dt =    0.063 s., v max =    34.43 m/s (h>0.000 m), volume = 346874.79 m3
# time :   20.875 s., dt =    0.063 s., v max =    34.49 m/s (h>0.000 m), volume = 347916.45 m3
# time :   20.938 s., dt =    0.063 s., v max =    34.56 m/s (h>0.000 m), volume = 348958.12 m3
#
# Draw at 21.000000 s (21.0%), estimated duration : 251.58s .
# time :   21.000 s., dt =    0.063 s., v max =    34.62 m/s (h>0.000 m), volume = 349999.79 m3
# time :   21.063 s., dt =    0.063 s., v max =    34.68 m/s (h>0.000 m), volume = 351041.45 m3
# time :   21.125 s., dt =    0.063 s., v max =    34.74 m/s (h>0.000 m), volume = 352083.12 m3
# time :   21.188 s., dt =    0.063 s., v max =    34.81 m/s (h>0.000 m), volume = 353124.78 m3
# time :   21.250 s., dt =    0.063 s., v max =    34.86 m/s (h>0.000 m), volume = 354166.44 m3
# time :   21.313 s., dt =    0.063 s., v max =    34.92 m/s (h>0.000 m), volume = 355208.11 m3
# time :   21.375 s., dt =    0.063 s., v max =    34.98 m/s (h>0.000 m), volume = 356249.77 m3
# time :   21.438 s., dt =    0.063 s., v max =    35.03 m/s (h>0.000 m), volume = 357291.43 m3
# time :   21.500 s., dt =    0.063 s., v max =    35.09 m/s (h>0.000 m), volume = 358333.10 m3
# time :   21.563 s., dt =    0.063 s., v max =    35.14 m/s (h>0.000 m), volume = 359374.77 m3
# time :   21.625 s., dt =    0.063 s., v max =    35.18 m/s (h>0.000 m), volume = 360416.43 m3
# time :   21.688 s., dt =    0.063 s., v max =    35.23 m/s (h>0.000 m), volume = 361458.10 m3
# time :   21.750 s., dt =    0.063 s., v max =    35.31 m/s (h>0.000 m), volume = 362499.76 m3
# time :   21.813 s., dt =    0.063 s., v max =    35.39 m/s (h>0.000 m), volume = 363541.43 m3
# time :   21.875 s., dt =    0.063 s., v max =    35.47 m/s (h>0.000 m), volume = 364583.10 m3
# time :   21.938 s., dt =    0.063 s., v max =    35.54 m/s (h>0.000 m), volume = 365624.76 m3
#
# Draw at 22.000000 s (22.0%), estimated duration : 252.77s .
# time :   22.000 s., dt =    0.063 s., v max =    35.62 m/s (h>0.000 m), volume = 366666.42 m3
# time :   22.063 s., dt =    0.063 s., v max =    35.69 m/s (h>0.000 m), volume = 367708.09 m3
# time :   22.125 s., dt =    0.063 s., v max =    35.76 m/s (h>0.000 m), volume = 368749.76 m3
# time :   22.188 s., dt =    0.063 s., v max =    35.83 m/s (h>0.000 m), volume = 369791.42 m3
# time :   22.250 s., dt =    0.063 s., v max =    35.89 m/s (h>0.000 m), volume = 370833.09 m3
# time :   22.313 s., dt =    0.063 s., v max =    35.96 m/s (h>0.000 m), volume = 371874.76 m3
# time :   22.375 s., dt =    0.063 s., v max =    36.02 m/s (h>0.000 m), volume = 372916.42 m3
# time :   22.438 s., dt =    0.063 s., v max =    36.08 m/s (h>0.000 m), volume = 373958.09 m3
# time :   22.500 s., dt =    0.063 s., v max =    36.13 m/s (h>0.000 m), volume = 374999.76 m3
# time :   22.563 s., dt =    0.063 s., v max =    36.19 m/s (h>0.000 m), volume = 376041.42 m3
# time :   22.625 s., dt =    0.063 s., v max =    36.24 m/s (h>0.000 m), volume = 377083.09 m3
# time :   22.688 s., dt =    0.063 s., v max =    36.29 m/s (h>0.000 m), volume = 378124.76 m3
# time :   22.750 s., dt =    0.063 s., v max =    36.34 m/s (h>0.000 m), volume = 379166.42 m3
# time :   22.813 s., dt =    0.063 s., v max =    36.38 m/s (h>0.000 m), volume = 380208.09 m3
# time :   22.875 s., dt =    0.063 s., v max =    36.43 m/s (h>0.000 m), volume = 381249.76 m3
# time :   22.938 s., dt =    0.063 s., v max =    36.47 m/s (h>0.000 m), volume = 382291.42 m3
#
# Draw at 23.000000 s (23.0%), estimated duration : 253.86s .
# time :   23.000 s., dt =    0.063 s., v max =    36.51 m/s (h>0.000 m), volume = 383333.09 m3
# time :   23.063 s., dt =    0.063 s., v max =    36.55 m/s (h>0.000 m), volume = 384374.75 m3
# time :   23.125 s., dt =    0.063 s., v max =    36.58 m/s (h>0.000 m), volume = 385416.42 m3
# time :   23.188 s., dt =    0.063 s., v max =    36.65 m/s (h>0.000 m), volume = 386458.09 m3
# time :   23.250 s., dt =    0.063 s., v max =    36.71 m/s (h>0.000 m), volume = 387499.75 m3
# time :   23.313 s., dt =    0.063 s., v max =    36.77 m/s (h>0.000 m), volume = 388541.42 m3
# time :   23.375 s., dt =    0.063 s., v max =    36.83 m/s (h>0.000 m), volume = 389583.08 m3
# time :   23.438 s., dt =    0.063 s., v max =    36.89 m/s (h>0.000 m), volume = 390624.75 m3
# time :   23.500 s., dt =    0.063 s., v max =    36.94 m/s (h>0.000 m), volume = 391666.41 m3
# time :   23.563 s., dt =    0.063 s., v max =    37.00 m/s (h>0.000 m), volume = 392708.08 m3
# time :   23.625 s., dt =    0.063 s., v max =    37.05 m/s (h>0.000 m), volume = 393749.75 m3
# time :   23.688 s., dt =    0.063 s., v max =    37.09 m/s (h>0.000 m), volume = 394791.41 m3
# time :   23.750 s., dt =    0.063 s., v max =    37.14 m/s (h>0.000 m), volume = 395833.08 m3
# time :   23.813 s., dt =    0.063 s., v max =    37.18 m/s (h>0.000 m), volume = 396874.75 m3
# time :   23.875 s., dt =    0.063 s., v max =    37.23 m/s (h>0.000 m), volume = 397916.41 m3
# time :   23.938 s., dt =    0.063 s., v max =    37.27 m/s (h>0.000 m), volume = 398958.08 m3
#
# Draw at 24.000000 s (24.0%), estimated duration : 254.81s .
# time :   24.000 s., dt =    0.063 s., v max =    37.31 m/s (h>0.000 m), volume = 399999.74 m3
# time :   24.063 s., dt =    0.063 s., v max =    37.34 m/s (h>0.000 m), volume = 401041.41 m3
# time :   24.125 s., dt =    0.063 s., v max =    37.38 m/s (h>0.000 m), volume = 402083.08 m3
# time :   24.188 s., dt =    0.063 s., v max =    37.41 m/s (h>0.000 m), volume = 403124.74 m3
# time :   24.250 s., dt =    0.063 s., v max =    37.45 m/s (h>0.000 m), volume = 404166.41 m3
# time :   24.313 s., dt =    0.063 s., v max =    37.48 m/s (h>0.000 m), volume = 405208.08 m3
# time :   24.375 s., dt =    0.063 s., v max =    37.51 m/s (h>0.000 m), volume = 406249.74 m3
# time :   24.438 s., dt =    0.063 s., v max =    37.54 m/s (h>0.000 m), volume = 407291.41 m3
# time :   24.500 s., dt =    0.063 s., v max =    37.57 m/s (h>0.000 m), volume = 408333.07 m3
# time :   24.563 s., dt =    0.063 s., v max =    37.61 m/s (h>0.000 m), volume = 409374.74 m3
# time :   24.625 s., dt =    0.063 s., v max =    37.66 m/s (h>0.000 m), volume = 410416.40 m3
# time :   24.688 s., dt =    0.063 s., v max =    37.70 m/s (h>0.000 m), volume = 411458.07 m3
# time :   24.750 s., dt =    0.063 s., v max =    37.74 m/s (h>0.000 m), volume = 412499.73 m3
# time :   24.813 s., dt =    0.063 s., v max =    37.79 m/s (h>0.000 m), volume = 413541.40 m3
# time :   24.875 s., dt =    0.063 s., v max =    37.83 m/s (h>0.000 m), volume = 414583.06 m3
# time :   24.938 s., dt =    0.063 s., v max =    37.86 m/s (h>0.000 m), volume = 415624.73 m3
#
# Draw at 25.000000 s (25.0%), estimated duration : 255.15s .
# time :   25.000 s., dt =    0.063 s., v max =    37.90 m/s (h>0.000 m), volume = 416666.40 m3
# time :   25.063 s., dt =    0.063 s., v max =    37.94 m/s (h>0.000 m), volume = 417708.06 m3
# time :   25.125 s., dt =    0.063 s., v max =    37.97 m/s (h>0.000 m), volume = 418749.73 m3
# time :   25.188 s., dt =    0.063 s., v max =    38.01 m/s (h>0.000 m), volume = 419791.39 m3
# time :   25.250 s., dt =    0.063 s., v max =    38.04 m/s (h>0.000 m), volume = 420833.06 m3
# time :   25.313 s., dt =    0.063 s., v max =    38.07 m/s (h>0.000 m), volume = 421874.72 m3
# time :   25.375 s., dt =    0.063 s., v max =    38.10 m/s (h>0.000 m), volume = 422916.38 m3
# time :   25.438 s., dt =    0.063 s., v max =    38.13 m/s (h>0.000 m), volume = 423958.05 m3
# time :   25.500 s., dt =    0.063 s., v max =    38.16 m/s (h>0.000 m), volume = 424999.71 m3
# time :   25.563 s., dt =    0.063 s., v max =    38.19 m/s (h>0.000 m), volume = 426041.37 m3
# time :   25.625 s., dt =    0.063 s., v max =    38.22 m/s (h>0.000 m), volume = 427083.04 m3
# time :   25.688 s., dt =    0.063 s., v max =    38.25 m/s (h>0.000 m), volume = 428124.71 m3
# time :   25.750 s., dt =    0.063 s., v max =    38.27 m/s (h>0.000 m), volume = 429166.37 m3
# time :   25.813 s., dt =    0.063 s., v max =    38.30 m/s (h>0.000 m), volume = 430208.03 m3
# time :   25.875 s., dt =    0.063 s., v max =    38.32 m/s (h>0.000 m), volume = 431249.70 m3
# time :   25.938 s., dt =    0.063 s., v max =    38.34 m/s (h>0.000 m), volume = 432291.36 m3
#
# Draw at 26.000000 s (26.0%), estimated duration : 255.00s .
# time :   26.000 s., dt =    0.063 s., v max =    38.37 m/s (h>0.000 m), volume = 433333.02 m3
# time :   26.063 s., dt =    0.063 s., v max =    38.39 m/s (h>0.000 m), volume = 434374.69 m3
# time :   26.125 s., dt =    0.063 s., v max =    38.41 m/s (h>0.000 m), volume = 435416.35 m3
# time :   26.188 s., dt =    0.063 s., v max =    38.43 m/s (h>0.000 m), volume = 436458.02 m3
# time :   26.250 s., dt =    0.063 s., v max =    38.46 m/s (h>0.000 m), volume = 437499.68 m3
# time :   26.313 s., dt =    0.063 s., v max =    38.50 m/s (h>0.000 m), volume = 438541.35 m3
# time :   26.375 s., dt =    0.063 s., v max =    38.53 m/s (h>0.000 m), volume = 439583.01 m3
# time :   26.438 s., dt =    0.063 s., v max =    38.56 m/s (h>0.000 m), volume = 440624.68 m3
# time :   26.500 s., dt =    0.063 s., v max =    38.59 m/s (h>0.000 m), volume = 441666.34 m3
# time :   26.563 s., dt =    0.063 s., v max =    38.61 m/s (h>0.000 m), volume = 442708.01 m3
# time :   26.625 s., dt =    0.063 s., v max =    38.64 m/s (h>0.000 m), volume = 443749.67 m3
# time :   26.688 s., dt =    0.063 s., v max =    38.67 m/s (h>0.000 m), volume = 444791.34 m3
# time :   26.750 s., dt =    0.063 s., v max =    38.70 m/s (h>0.000 m), volume = 445833.00 m3
# time :   26.813 s., dt =    0.063 s., v max =    38.72 m/s (h>0.000 m), volume = 446874.67 m3
# time :   26.875 s., dt =    0.063 s., v max =    38.75 m/s (h>0.000 m), volume = 447916.33 m3
# time :   26.938 s., dt =    0.063 s., v max =    38.77 m/s (h>0.000 m), volume = 448958.00 m3
#
# Draw at 27.000000 s (27.0%), estimated duration : 254.70s .
# time :   27.000 s., dt =    0.063 s., v max =    38.80 m/s (h>0.000 m), volume = 449999.66 m3
# time :   27.063 s., dt =    0.063 s., v max =    38.82 m/s (h>0.000 m), volume = 451041.33 m3
# time :   27.125 s., dt =    0.063 s., v max =    38.85 m/s (h>0.000 m), volume = 452082.98 m3
# time :   27.188 s., dt =    0.063 s., v max =    38.87 m/s (h>0.000 m), volume = 453124.65 m3
# time :   27.250 s., dt =    0.063 s., v max =    38.90 m/s (h>0.000 m), volume = 454166.31 m3
# time :   27.313 s., dt =    0.063 s., v max =    38.92 m/s (h>0.000 m), volume = 455207.98 m3
# time :   27.375 s., dt =    0.063 s., v max =    38.94 m/s (h>0.000 m), volume = 456249.64 m3
# time :   27.438 s., dt =    0.063 s., v max =    38.96 m/s (h>0.000 m), volume = 457291.30 m3
# time :   27.500 s., dt =    0.063 s., v max =    38.99 m/s (h>0.000 m), volume = 458332.96 m3
# time :   27.563 s., dt =    0.063 s., v max =    39.01 m/s (h>0.000 m), volume = 459374.63 m3
# time :   27.625 s., dt =    0.063 s., v max =    39.03 m/s (h>0.000 m), volume = 460416.29 m3
# time :   27.688 s., dt =    0.063 s., v max =    39.05 m/s (h>0.000 m), volume = 461457.95 m3
# time :   27.750 s., dt =    0.063 s., v max =    39.07 m/s (h>0.000 m), volume = 462499.61 m3
# time :   27.813 s., dt =    0.063 s., v max =    39.09 m/s (h>0.000 m), volume = 463541.28 m3
# time :   27.875 s., dt =    0.063 s., v max =    39.11 m/s (h>0.000 m), volume = 464582.94 m3
# time :   27.938 s., dt =    0.063 s., v max =    39.13 m/s (h>0.000 m), volume = 465624.61 m3
#
# Draw at 28.000000 s (28.0%), estimated duration : 253.93s .
# time :   28.000 s., dt =    0.063 s., v max =    39.14 m/s (h>0.000 m), volume = 466666.27 m3
# time :   28.063 s., dt =    0.063 s., v max =    39.16 m/s (h>0.000 m), volume = 467707.93 m3
# time :   28.125 s., dt =    0.063 s., v max =    39.18 m/s (h>0.000 m), volume = 468749.60 m3
# time :   28.188 s., dt =    0.063 s., v max =    39.20 m/s (h>0.000 m), volume = 469791.26 m3
# time :   28.250 s., dt =    0.063 s., v max =    39.22 m/s (h>0.000 m), volume = 470832.92 m3
# time :   28.313 s., dt =    0.063 s., v max =    39.23 m/s (h>0.000 m), volume = 471874.58 m3
# time :   28.375 s., dt =    0.063 s., v max =    39.25 m/s (h>0.000 m), volume = 472916.24 m3
# time :   28.438 s., dt =    0.063 s., v max =    39.27 m/s (h>0.000 m), volume = 473957.90 m3
# time :   28.500 s., dt =    0.063 s., v max =    39.28 m/s (h>0.000 m), volume = 474999.57 m3
# time :   28.563 s., dt =    0.063 s., v max =    39.30 m/s (h>0.000 m), volume = 476041.23 m3
# time :   28.625 s., dt =    0.063 s., v max =    39.32 m/s (h>0.000 m), volume = 477082.89 m3
# time :   28.688 s., dt =    0.063 s., v max =    39.33 m/s (h>0.000 m), volume = 478124.56 m3
# time :   28.750 s., dt =    0.063 s., v max =    39.35 m/s (h>0.000 m), volume = 479166.22 m3
# time :   28.813 s., dt =    0.063 s., v max =    39.37 m/s (h>0.000 m), volume = 480207.87 m3
# time :   28.875 s., dt =    0.063 s., v max =    39.39 m/s (h>0.000 m), volume = 481249.54 m3
# time :   28.938 s., dt =    0.063 s., v max =    39.41 m/s (h>0.000 m), volume = 482291.20 m3
#
# Draw at 29.000000 s (29.0%), estimated duration : 252.64s .
# time :   29.000 s., dt =    0.063 s., v max =    39.43 m/s (h>0.000 m), volume = 483332.86 m3
# time :   29.063 s., dt =    0.063 s., v max =    39.45 m/s (h>0.000 m), volume = 484374.53 m3
# time :   29.125 s., dt =    0.063 s., v max =    39.47 m/s (h>0.000 m), volume = 485416.18 m3
# time :   29.188 s., dt =    0.063 s., v max =    39.49 m/s (h>0.000 m), volume = 486457.84 m3
# time :   29.250 s., dt =    0.063 s., v max =    39.51 m/s (h>0.000 m), volume = 487499.50 m3
# time :   29.313 s., dt =    0.063 s., v max =    39.53 m/s (h>0.000 m), volume = 488541.16 m3
# time :   29.375 s., dt =    0.063 s., v max =    39.54 m/s (h>0.000 m), volume = 489582.83 m3
# time :   29.438 s., dt =    0.063 s., v max =    39.56 m/s (h>0.000 m), volume = 490624.48 m3
# time :   29.500 s., dt =    0.063 s., v max =    39.58 m/s (h>0.000 m), volume = 491666.15 m3
# time :   29.563 s., dt =    0.063 s., v max =    39.60 m/s (h>0.000 m), volume = 492707.81 m3
# time :   29.625 s., dt =    0.063 s., v max =    39.61 m/s (h>0.000 m), volume = 493749.47 m3
# time :   29.688 s., dt =    0.063 s., v max =    39.63 m/s (h>0.000 m), volume = 494791.13 m3
# time :   29.750 s., dt =    0.063 s., v max =    39.65 m/s (h>0.000 m), volume = 495832.80 m3
# time :   29.813 s., dt =    0.063 s., v max =    39.66 m/s (h>0.000 m), volume = 496874.46 m3
# time :   29.875 s., dt =    0.063 s., v max =    39.68 m/s (h>0.000 m), volume = 497916.12 m3
# time :   29.938 s., dt =    0.063 s., v max =    39.69 m/s (h>0.000 m), volume = 498957.79 m3
#
# Draw at 30.000000 s (30.0%), estimated duration : 251.57s .
# time :   30.000 s., dt =    0.063 s., v max =    39.71 m/s (h>0.000 m), volume = 499999.45 m3
# time :   30.063 s., dt =    0.063 s., v max =    39.72 m/s (h>0.000 m), volume = 501041.12 m3
# time :   30.125 s., dt =    0.063 s., v max =    39.74 m/s (h>0.000 m), volume = 502082.78 m3
# time :   30.188 s., dt =    0.063 s., v max =    39.75 m/s (h>0.000 m), volume = 503124.45 m3
# time :   30.250 s., dt =    0.063 s., v max =    39.77 m/s (h>0.000 m), volume = 504166.11 m3
# time :   30.313 s., dt =    0.063 s., v max =    39.78 m/s (h>0.000 m), volume = 505207.78 m3
# time :   30.375 s., dt =    0.063 s., v max =    39.80 m/s (h>0.000 m), volume = 506249.44 m3
# time :   30.438 s., dt =    0.063 s., v max =    39.81 m/s (h>0.000 m), volume = 507291.10 m3
# time :   30.500 s., dt =    0.063 s., v max =    39.82 m/s (h>0.000 m), volume = 508332.77 m3
# time :   30.563 s., dt =    0.063 s., v max =    39.84 m/s (h>0.000 m), volume = 509374.43 m3
# time :   30.625 s., dt =    0.063 s., v max =    39.85 m/s (h>0.000 m), volume = 510416.10 m3
# time :   30.688 s., dt =    0.063 s., v max =    39.86 m/s (h>0.000 m), volume = 511457.76 m3
# time :   30.750 s., dt =    0.063 s., v max =    39.88 m/s (h>0.000 m), volume = 512499.43 m3
# time :   30.813 s., dt =    0.063 s., v max =    39.89 m/s (h>0.000 m), volume = 513541.10 m3
# time :   30.875 s., dt =    0.063 s., v max =    39.92 m/s (h>0.000 m), volume = 514582.76 m3
# time :   30.938 s., dt =    0.063 s., v max =    39.95 m/s (h>0.000 m), volume = 515624.43 m3
#
# Draw at 31.000000 s (31.0%), estimated duration : 250.27s .
# time :   31.000 s., dt =    0.063 s., v max =    39.99 m/s (h>0.000 m), volume = 516666.09 m3
# time :   31.063 s., dt =    0.063 s., v max =    40.03 m/s (h>0.000 m), volume = 517707.76 m3
# time :   31.125 s., dt =    0.063 s., v max =    40.08 m/s (h>0.000 m), volume = 518749.42 m3
# time :   31.188 s., dt =    0.063 s., v max =    40.12 m/s (h>0.000 m), volume = 519791.09 m3
# time :   31.250 s., dt =    0.063 s., v max =    40.17 m/s (h>0.000 m), volume = 520832.75 m3
# time :   31.313 s., dt =    0.063 s., v max =    40.21 m/s (h>0.000 m), volume = 521874.41 m3
# time :   31.375 s., dt =    0.063 s., v max =    40.26 m/s (h>0.000 m), volume = 522916.08 m3
# time :   31.438 s., dt =    0.063 s., v max =    40.30 m/s (h>0.000 m), volume = 523957.74 m3
# time :   31.500 s., dt =    0.063 s., v max =    40.35 m/s (h>0.000 m), volume = 524999.40 m3
# time :   31.563 s., dt =    0.063 s., v max =    40.39 m/s (h>0.000 m), volume = 526041.07 m3
# time :   31.625 s., dt =    0.063 s., v max =    40.44 m/s (h>0.000 m), volume = 527082.73 m3
# time :   31.688 s., dt =    0.063 s., v max =    40.49 m/s (h>0.000 m), volume = 528124.40 m3
# time :   31.750 s., dt =    0.063 s., v max =    40.53 m/s (h>0.000 m), volume = 529166.06 m3
# time :   31.813 s., dt =    0.063 s., v max =    40.57 m/s (h>0.000 m), volume = 530207.73 m3
# time :   31.875 s., dt =    0.063 s., v max =    40.62 m/s (h>0.000 m), volume = 531249.39 m3
# time :   31.938 s., dt =    0.063 s., v max =    40.66 m/s (h>0.000 m), volume = 532291.05 m3
#
# Draw at 32.000000 s (32.0%), estimated duration : 248.70s .
# time :   32.000 s., dt =    0.063 s., v max =    40.71 m/s (h>0.000 m), volume = 533332.72 m3
# time :   32.063 s., dt =    0.063 s., v max =    40.75 m/s (h>0.000 m), volume = 534374.38 m3
# time :   32.125 s., dt =    0.063 s., v max =    40.79 m/s (h>0.000 m), volume = 535416.04 m3
# time :   32.188 s., dt =    0.063 s., v max =    40.83 m/s (h>0.000 m), volume = 536457.70 m3
# time :   32.250 s., dt =    0.063 s., v max =    40.87 m/s (h>0.000 m), volume = 537499.36 m3
# time :   32.313 s., dt =    0.063 s., v max =    40.92 m/s (h>0.000 m), volume = 538541.02 m3
# time :   32.375 s., dt =    0.063 s., v max =    40.96 m/s (h>0.000 m), volume = 539582.69 m3
# time :   32.438 s., dt =    0.063 s., v max =    40.99 m/s (h>0.000 m), volume = 540624.35 m3
# time :   32.500 s., dt =    0.063 s., v max =    41.03 m/s (h>0.000 m), volume = 541666.01 m3
# time :   32.563 s., dt =    0.063 s., v max =    41.07 m/s (h>0.000 m), volume = 542707.68 m3
# time :   32.625 s., dt =    0.063 s., v max =    41.11 m/s (h>0.000 m), volume = 543749.34 m3
# time :   32.688 s., dt =    0.063 s., v max =    41.14 m/s (h>0.000 m), volume = 544791.01 m3
# time :   32.750 s., dt =    0.063 s., v max =    41.18 m/s (h>0.000 m), volume = 545832.67 m3
# time :   32.813 s., dt =    0.063 s., v max =    41.21 m/s (h>0.000 m), volume = 546874.34 m3
# time :   32.875 s., dt =    0.063 s., v max =    41.25 m/s (h>0.000 m), volume = 547916.00 m3
# time :   32.938 s., dt =    0.063 s., v max =    41.28 m/s (h>0.000 m), volume = 548957.67 m3
#
# Draw at 33.000000 s (33.0%), estimated duration : 246.46s .
# time :   33.000 s., dt =    0.063 s., v max =    41.31 m/s (h>0.000 m), volume = 549999.33 m3
# time :   33.063 s., dt =    0.063 s., v max =    41.34 m/s (h>0.000 m), volume = 551041.00 m3
# time :   33.125 s., dt =    0.063 s., v max =    41.37 m/s (h>0.000 m), volume = 552082.66 m3
# time :   33.188 s., dt =    0.063 s., v max =    41.40 m/s (h>0.000 m), volume = 553124.33 m3
# time :   33.250 s., dt =    0.063 s., v max =    41.43 m/s (h>0.000 m), volume = 554165.99 m3
# time :   33.313 s., dt =    0.063 s., v max =    41.46 m/s (h>0.000 m), volume = 555207.66 m3
# time :   33.375 s., dt =    0.063 s., v max =    41.49 m/s (h>0.000 m), volume = 556249.32 m3
# time :   33.438 s., dt =    0.063 s., v max =    41.52 m/s (h>0.000 m), volume = 557290.99 m3
# time :   33.500 s., dt =    0.063 s., v max =    41.54 m/s (h>0.000 m), volume = 558332.65 m3
# time :   33.563 s., dt =    0.063 s., v max =    41.57 m/s (h>0.000 m), volume = 559374.31 m3
# time :   33.625 s., dt =    0.063 s., v max =    41.59 m/s (h>0.000 m), volume = 560415.98 m3
# time :   33.688 s., dt =    0.063 s., v max =    41.61 m/s (h>0.000 m), volume = 561457.64 m3
# time :   33.750 s., dt =    0.063 s., v max =    41.64 m/s (h>0.000 m), volume = 562499.30 m3
# time :   33.813 s., dt =    0.063 s., v max =    41.66 m/s (h>0.000 m), volume = 563540.97 m3
# time :   33.875 s., dt =    0.063 s., v max =    41.69 m/s (h>0.000 m), volume = 564582.63 m3
# time :   33.938 s., dt =    0.063 s., v max =    41.73 m/s (h>0.000 m), volume = 565624.30 m3
#
# Draw at 34.000000 s (34.0%), estimated duration : 244.00s .
# time :   34.000 s., dt =    0.063 s., v max =    41.76 m/s (h>0.000 m), volume = 566665.97 m3
# time :   34.063 s., dt =    0.063 s., v max =    41.80 m/s (h>0.000 m), volume = 567707.63 m3
# time :   34.125 s., dt =    0.063 s., v max =    41.83 m/s (h>0.000 m), volume = 568749.30 m3
# time :   34.188 s., dt =    0.063 s., v max =    41.87 m/s (h>0.000 m), volume = 569790.96 m3
# time :   34.250 s., dt =    0.063 s., v max =    41.90 m/s (h>0.000 m), volume = 570832.63 m3
# time :   34.313 s., dt =    0.063 s., v max =    41.93 m/s (h>0.000 m), volume = 571874.29 m3
# time :   34.375 s., dt =    0.063 s., v max =    41.96 m/s (h>0.000 m), volume = 572915.96 m3
# time :   34.438 s., dt =    0.063 s., v max =    41.99 m/s (h>0.000 m), volume = 573957.62 m3
# time :   34.500 s., dt =    0.063 s., v max =    42.02 m/s (h>0.000 m), volume = 574999.29 m3
# time :   34.563 s., dt =    0.063 s., v max =    42.05 m/s (h>0.000 m), volume = 576040.95 m3
# time :   34.625 s., dt =    0.063 s., v max =    42.07 m/s (h>0.000 m), volume = 577082.61 m3
# time :   34.688 s., dt =    0.063 s., v max =    42.10 m/s (h>0.000 m), volume = 578124.28 m3
# time :   34.750 s., dt =    0.063 s., v max =    42.12 m/s (h>0.000 m), volume = 579165.94 m3
# time :   34.813 s., dt =    0.063 s., v max =    42.15 m/s (h>0.000 m), volume = 580207.61 m3
# time :   34.875 s., dt =    0.063 s., v max =    42.17 m/s (h>0.000 m), volume = 581249.26 m3
# time :   34.938 s., dt =    0.063 s., v max =    42.20 m/s (h>0.000 m), volume = 582290.93 m3
#
# Draw at 35.000000 s (35.0%), estimated duration : 241.54s .
# time :   35.000 s., dt =    0.063 s., v max =    42.22 m/s (h>0.000 m), volume = 583332.59 m3
# time :   35.063 s., dt =    0.063 s., v max =    42.24 m/s (h>0.000 m), volume = 584374.26 m3
# time :   35.125 s., dt =    0.063 s., v max =    42.26 m/s (h>0.000 m), volume = 585415.92 m3
# time :   35.188 s., dt =    0.063 s., v max =    42.28 m/s (h>0.000 m), volume = 586457.58 m3
# time :   35.250 s., dt =    0.063 s., v max =    42.30 m/s (h>0.000 m), volume = 587499.25 m3
# time :   35.313 s., dt =    0.063 s., v max =    42.32 m/s (h>0.000 m), volume = 588540.92 m3
# time :   35.375 s., dt =    0.063 s., v max =    42.34 m/s (h>0.000 m), volume = 589582.58 m3
# time :   35.438 s., dt =    0.063 s., v max =    42.36 m/s (h>0.000 m), volume = 590624.24 m3
# time :   35.500 s., dt =    0.063 s., v max =    42.38 m/s (h>0.000 m), volume = 591665.90 m3
# time :   35.563 s., dt =    0.063 s., v max =    42.39 m/s (h>0.000 m), volume = 592707.57 m3
# time :   35.625 s., dt =    0.063 s., v max =    42.41 m/s (h>0.000 m), volume = 593749.23 m3
# ...
# time :   90.438 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.54 m3
# time :   90.500 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.53 m3
# time :   90.563 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.53 m3
# time :   90.625 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.53 m3
# time :   90.688 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.52 m3
# time :   90.750 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.52 m3
# time :   90.813 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.52 m3
# time :   90.875 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.52 m3
# time :   90.938 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.51 m3
#
# Draw at 91.000000 s (91.0%), estimated duration : 36.05s .
# time :   91.000 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.51 m3
# time :   91.063 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.51 m3
# time :   91.125 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.51 m3
# time :   91.188 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.50 m3
# time :   91.250 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.50 m3
# time :   91.313 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.50 m3
# time :   91.375 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.50 m3
# time :   91.438 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.49 m3
# time :   91.500 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.49 m3
# time :   91.563 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.48 m3
# time :   91.625 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.48 m3
# time :   91.688 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.48 m3
# time :   91.750 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.47 m3
# time :   91.813 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.47 m3
# time :   91.875 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.46 m3
# time :   91.938 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.46 m3
#
# Draw at 92.000000 s (92.0%), estimated duration : 32.05s .
# time :   92.000 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.46 m3
# time :   92.063 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.45 m3
# time :   92.125 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.45 m3
# time :   92.188 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.45 m3
# time :   92.250 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.45 m3
# time :   92.313 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.45 m3
# time :   92.375 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.45 m3
# time :   92.438 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.44 m3
# time :   92.500 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.44 m3
# time :   92.563 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.44 m3
# time :   92.625 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.43 m3
# time :   92.688 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.42 m3
# time :   92.750 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.42 m3
# time :   92.813 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.41 m3
# time :   92.875 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.41 m3
# time :   92.938 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.41 m3
#
# Draw at 93.000000 s (93.0%), estimated duration : 28.05s .
# time :   93.000 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.41 m3
# time :   93.063 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.40 m3
# time :   93.125 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.40 m3
# time :   93.188 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.39 m3
# time :   93.250 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.39 m3
# time :   93.313 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.38 m3
# time :   93.375 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.37 m3
# time :   93.438 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.37 m3
# time :   93.500 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.37 m3
# time :   93.563 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.37 m3
# time :   93.625 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.36 m3
# time :   93.688 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.36 m3
# time :   93.750 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.36 m3
# time :   93.813 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.35 m3
# time :   93.875 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.35 m3
# time :   93.938 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.35 m3
#
# Draw at 94.000000 s (94.0%), estimated duration : 24.04s .
# time :   94.000 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.35 m3
# time :   94.063 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.34 m3
# time :   94.125 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.34 m3
# time :   94.188 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.33 m3
# time :   94.250 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.33 m3
# time :   94.313 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.33 m3
# time :   94.375 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.32 m3
# time :   94.438 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.32 m3
# time :   94.500 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.32 m3
# time :   94.563 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.31 m3
# time :   94.625 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.31 m3
# time :   94.688 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.31 m3
# time :   94.750 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.30 m3
# time :   94.813 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.30 m3
# time :   94.875 s., dt =    0.063 s., v max =    45.17 m/s (h>0.000 m), volume = 998954.29 m3
# time :   94.938 s., dt =    0.063 s., v max =    45.16 m/s (h>0.000 m), volume = 998954.29 m3
#
# Draw at 95.000000 s (95.0%), estimated duration : 20.03s .
# time :   95.000 s., dt =    0.063 s., v max =    45.16 m/s (h>0.000 m), volume = 998954.29 m3
# time :   95.063 s., dt =    0.063 s., v max =    45.16 m/s (h>0.000 m), volume = 998954.28 m3
# time :   95.125 s., dt =    0.063 s., v max =    45.16 m/s (h>0.000 m), volume = 998954.28 m3
# time :   95.188 s., dt =    0.063 s., v max =    45.16 m/s (h>0.000 m), volume = 998954.27 m3
# time :   95.250 s., dt =    0.063 s., v max =    45.16 m/s (h>0.000 m), volume = 998954.27 m3
# time :   95.313 s., dt =    0.063 s., v max =    45.16 m/s (h>0.000 m), volume = 998954.27 m3
# time :   95.375 s., dt =    0.063 s., v max =    45.16 m/s (h>0.000 m), volume = 998954.27 m3
# time :   95.438 s., dt =    0.063 s., v max =    45.16 m/s (h>0.000 m), volume = 998954.27 m3
# time :   95.500 s., dt =    0.063 s., v max =    45.15 m/s (h>0.000 m), volume = 998954.26 m3
# time :   95.563 s., dt =    0.063 s., v max =    45.15 m/s (h>0.000 m), volume = 998954.26 m3
# time :   95.625 s., dt =    0.063 s., v max =    45.15 m/s (h>0.000 m), volume = 998954.26 m3
# time :   95.688 s., dt =    0.063 s., v max =    45.15 m/s (h>0.000 m), volume = 998954.25 m3
# time :   95.750 s., dt =    0.063 s., v max =    45.15 m/s (h>0.000 m), volume = 998954.25 m3
# time :   95.813 s., dt =    0.063 s., v max =    45.14 m/s (h>0.000 m), volume = 998954.24 m3
# time :   95.875 s., dt =    0.063 s., v max =    45.14 m/s (h>0.000 m), volume = 998954.24 m3
# time :   95.938 s., dt =    0.063 s., v max =    45.14 m/s (h>0.000 m), volume = 998954.23 m3
#
# Draw at 96.000000 s (96.0%), estimated duration : 16.03s .
# time :   96.000 s., dt =    0.063 s., v max =    45.14 m/s (h>0.000 m), volume = 998954.22 m3
# time :   96.063 s., dt =    0.063 s., v max =    45.14 m/s (h>0.000 m), volume = 998954.22 m3
# time :   96.125 s., dt =    0.063 s., v max =    45.13 m/s (h>0.000 m), volume = 998954.22 m3
# time :   96.188 s., dt =    0.063 s., v max =    45.13 m/s (h>0.000 m), volume = 998954.22 m3
# time :   96.250 s., dt =    0.063 s., v max =    45.13 m/s (h>0.000 m), volume = 998954.21 m3
# time :   96.313 s., dt =    0.063 s., v max =    45.12 m/s (h>0.000 m), volume = 998954.21 m3
# time :   96.375 s., dt =    0.063 s., v max =    45.12 m/s (h>0.000 m), volume = 998954.21 m3
# time :   96.438 s., dt =    0.063 s., v max =    45.12 m/s (h>0.000 m), volume = 998954.20 m3
# time :   96.500 s., dt =    0.063 s., v max =    45.11 m/s (h>0.000 m), volume = 998954.20 m3
# time :   96.563 s., dt =    0.063 s., v max =    45.11 m/s (h>0.000 m), volume = 998954.20 m3
# time :   96.625 s., dt =    0.063 s., v max =    45.10 m/s (h>0.000 m), volume = 998954.19 m3
# time :   96.688 s., dt =    0.063 s., v max =    45.10 m/s (h>0.000 m), volume = 998954.19 m3
# time :   96.750 s., dt =    0.063 s., v max =    45.09 m/s (h>0.000 m), volume = 998954.18 m3
# time :   96.813 s., dt =    0.063 s., v max =    45.09 m/s (h>0.000 m), volume = 998954.18 m3
# time :   96.875 s., dt =    0.063 s., v max =    45.08 m/s (h>0.000 m), volume = 998954.17 m3
# time :   96.938 s., dt =    0.063 s., v max =    45.08 m/s (h>0.000 m), volume = 998954.17 m3
#
# Draw at 97.000000 s (97.0%), estimated duration : 12.02s .
# time :   97.000 s., dt =    0.063 s., v max =    45.07 m/s (h>0.000 m), volume = 998954.16 m3
# time :   97.063 s., dt =    0.063 s., v max =    45.06 m/s (h>0.000 m), volume = 998954.15 m3
# time :   97.125 s., dt =    0.063 s., v max =    45.06 m/s (h>0.000 m), volume = 998954.15 m3
# time :   97.188 s., dt =    0.063 s., v max =    45.05 m/s (h>0.000 m), volume = 998954.14 m3
# time :   97.250 s., dt =    0.063 s., v max =    45.04 m/s (h>0.000 m), volume = 998954.13 m3
# time :   97.313 s., dt =    0.063 s., v max =    45.04 m/s (h>0.000 m), volume = 998954.12 m3
# time :   97.375 s., dt =    0.063 s., v max =    45.03 m/s (h>0.000 m), volume = 998954.11 m3
# time :   97.438 s., dt =    0.063 s., v max =    45.02 m/s (h>0.000 m), volume = 998954.10 m3
# time :   97.500 s., dt =    0.063 s., v max =    45.01 m/s (h>0.000 m), volume = 998954.10 m3
# time :   97.563 s., dt =    0.063 s., v max =    45.00 m/s (h>0.000 m), volume = 998954.09 m3
# time :   97.625 s., dt =    0.063 s., v max =    44.99 m/s (h>0.000 m), volume = 998954.08 m3
# time :   97.688 s., dt =    0.063 s., v max =    44.98 m/s (h>0.000 m), volume = 998954.08 m3
# time :   97.750 s., dt =    0.063 s., v max =    44.97 m/s (h>0.000 m), volume = 998954.07 m3
# time :   97.813 s., dt =    0.063 s., v max =    44.96 m/s (h>0.000 m), volume = 998954.07 m3
# time :   97.875 s., dt =    0.063 s., v max =    44.95 m/s (h>0.000 m), volume = 998954.07 m3
# time :   97.938 s., dt =    0.063 s., v max =    44.94 m/s (h>0.000 m), volume = 998954.06 m3
#
# Draw at 98.000000 s (98.0%), estimated duration :  8.01s .
# time :   98.000 s., dt =    0.063 s., v max =    44.93 m/s (h>0.000 m), volume = 998954.05 m3
# time :   98.063 s., dt =    0.063 s., v max =    44.92 m/s (h>0.000 m), volume = 998954.05 m3
# time :   98.125 s., dt =    0.063 s., v max =    44.90 m/s (h>0.000 m), volume = 998954.05 m3
# time :   98.188 s., dt =    0.063 s., v max =    44.89 m/s (h>0.000 m), volume = 998954.04 m3
# time :   98.250 s., dt =    0.063 s., v max =    44.88 m/s (h>0.000 m), volume = 998954.04 m3
# time :   98.313 s., dt =    0.063 s., v max =    44.86 m/s (h>0.000 m), volume = 998954.03 m3
# time :   98.375 s., dt =    0.063 s., v max =    44.85 m/s (h>0.000 m), volume = 998954.03 m3
# time :   98.438 s., dt =    0.063 s., v max =    44.83 m/s (h>0.000 m), volume = 998954.03 m3
# time :   98.500 s., dt =    0.063 s., v max =    44.82 m/s (h>0.000 m), volume = 998954.03 m3
# time :   98.563 s., dt =    0.063 s., v max =    44.80 m/s (h>0.000 m), volume = 998954.03 m3
# time :   98.625 s., dt =    0.063 s., v max =    44.79 m/s (h>0.000 m), volume = 998954.03 m3
# time :   98.688 s., dt =    0.063 s., v max =    44.77 m/s (h>0.000 m), volume = 998954.02 m3
# time :   98.750 s., dt =    0.063 s., v max =    44.75 m/s (h>0.000 m), volume = 998954.01 m3
# time :   98.813 s., dt =    0.063 s., v max =    44.74 m/s (h>0.000 m), volume = 998954.01 m3
# time :   98.875 s., dt =    0.063 s., v max =    44.72 m/s (h>0.000 m), volume = 998954.00 m3
# time :   98.938 s., dt =    0.063 s., v max =    44.70 m/s (h>0.000 m), volume = 998954.00 m3
#
# Draw at 99.000000 s (99.0%), estimated duration :  4.01s .
# time :   99.000 s., dt =    0.063 s., v max =    44.68 m/s (h>0.000 m), volume = 998954.00 m3
# time :   99.063 s., dt =    0.063 s., v max =    44.66 m/s (h>0.000 m), volume = 998954.00 m3
# time :   99.125 s., dt =    0.063 s., v max =    44.64 m/s (h>0.000 m), volume = 998953.99 m3
# time :   99.188 s., dt =    0.063 s., v max =    44.62 m/s (h>0.000 m), volume = 998953.99 m3
# time :   99.250 s., dt =    0.063 s., v max =    44.60 m/s (h>0.000 m), volume = 998953.99 m3
# time :   99.313 s., dt =    0.063 s., v max =    44.57 m/s (h>0.000 m), volume = 998953.98 m3
# time :   99.375 s., dt =    0.063 s., v max =    44.55 m/s (h>0.000 m), volume = 998953.98 m3
# time :   99.438 s., dt =    0.063 s., v max =    44.53 m/s (h>0.000 m), volume = 998953.97 m3
# time :   99.500 s., dt =    0.063 s., v max =    44.51 m/s (h>0.000 m), volume = 998953.97 m3
# time :   99.563 s., dt =    0.063 s., v max =    44.48 m/s (h>0.000 m), volume = 998953.97 m3
# time :   99.625 s., dt =    0.063 s., v max =    44.46 m/s (h>0.000 m), volume = 998953.97 m3
# time :   99.688 s., dt =    0.063 s., v max =    44.43 m/s (h>0.000 m), volume = 998953.96 m3
# time :   99.750 s., dt =    0.063 s., v max =    44.41 m/s (h>0.000 m), volume = 998953.96 m3
# time :   99.813 s., dt =    0.063 s., v max =    44.38 m/s (h>0.000 m), volume = 998953.96 m3
# time :   99.875 s., dt =    0.063 s., v max =    44.35 m/s (h>0.000 m), volume = 998953.96 m3
# time :   99.938 s., dt =    0.063 s., v max =    44.32 m/s (h>0.000 m), volume = 998953.96 m3
#
# Draw at 100.000000 s (100.0%), estimated duration : -0.00s .
#
# Final time :  100.000 s., dt =    0.063 s., v max =    44.30, volume = 998953.95 m3
# Elapsed time is 400.681 seconds.
#
#
#
#      ___________  Version n� 4.0.0   ___________
#      |                                                 |
#      | VolcFlow is a numerical code for the simulation |
#      |  of geophysical flows on complex topographies.  |
#      |          It is written by Karim Kelfoun,        |
#      |      Laboratoire Magmas et Volcans, UMR 6524    |
#      |           Clermont-Auvergne University          |
#      |      6, avenue Blaise Pascal, 63170 Aubi�re     |
#      |           <a href = "http://https://lmv.uca.fr/volcflow/">Visit the VolcFlow web site.</a>          |
#      |                                                 |
#      |   ---       License : Karim Kelfoun       ---   |
#      ���������������������������������������������������
# ans = 0

# %% [markdown]
# ### IMEX_SfloW_2D

# %%
os.chdir("IMEX_SfloW_2D")
f=open("./input_ellipsoid.py","r+")
inp = f.readlines()
inp[0] = f"""DEM_folder = '../DEMs_PDC_Benchmark/'\n"""
inp[1] = f"""DEM_file = 'bend_arc.asc'\n"""
inp[2] = f"""x1 = 495\n"""
inp[3] = f"""y1 = 545\n"""
inp[4] = f"""x2 = 505\n"""
inp[5] = f"""y2 = 555\n"""
inp[6] = f"""semi_width = 50 \n"""
inp[7] = f"""vol = 1e6\n"""
f.seek(0)
f.writelines(inp)
f.truncate()
f.close()
# !python create_input_ellipsoid.py

f=open("./IMEX_SfloW2D.inp","r+")
inp = f.readlines()
inp[1] =  'RUN_NAME="bend_arc",\n'
inp[2] =  f"""RESTART=T,\n"""
inp[3] =  f"""T_START=  0     ,\n"""
inp[4] =  f"""T_END=  100,\n"""
inp[5] =  f"""DT_OUTPUT=  10,\n"""
inp[13] = f"""X0={xll},\n"""
inp[14] = f""" Y0=  {yll}     ,\n"""
inp[16] = f""" COMP_CELLS_X=  300,\n"""
inp[17] = f""" COMP_CELLS_Y=  1000,	\n"""
inp[18] = f""" CELL_SIZE = 5.0D0    ,\n"""
f.seek(0)
f.writelines(inp)
f.truncate()
f.close()

p = subprocess.Popen(['./IMEX_SfloW2D'], stdin=subprocess.PIPE, shell=True)
os.chdir("..")
# Out:
# ----------------------------------------------
# Pre-processing tool by M. de' Michieli Vitturi
# ----------------------------------------------
#
# Reading DEM file: ../DEMs_PDC_Benchmark/bend_arc.asc
# /home/jovyan/PDC Benchmark/IMEX_SfloW_2D/create_input_ellipsoid.py:323: FutureWarning: The 'delim_whitespace' keyword in pd.read_table is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   DEM = pd.read_table(DEM_file,
# Completed reading DEM, shape: (1000, 300)
#
# semi_axis0 66.53350197457343
# Ellissoid center: 495 545 1561.1299756469452
# Ellipsoid semi-axis:  66.53350197457343 66.53350197457343 47.14444097897649
# Rotation angle:  207.47443162627715
# Initial volume 67852.32216820629  m3
# semi_axis2 266.1340078982937
# Ellissoid center: 495 545 1631.0369496198975
# Ellipsoid semi-axis:  266.13400789829365 266.1340078982937 117.05141495192879
# Rotation angle:  189.0276129507151
# Initial volume 2127265.9876439115  m3
# semi_axis1 219.7863950104538
# Ellissoid center: 495 545 1615.0881721052144
# Ellipsoid semi-axis:  219.78639501045382 219.7863950104538 101.10263743724568
# Rotation angle:  193.5704343851615
# Initial volume 1219150.4275893252  m3
# semi_axis1 184.20078500662453
# Ellissoid center: 495 545 1603.1302871949447
# Ellipsoid semi-axis:  184.20078500662453 184.20078500662453 89.14475252697594
# Rotation angle:  194.58891873287465
# Initial volume 737775.4862747333  m3
# semi_axis1 211.52334943748602
# Ellissoid center: 495 545 1612.2734953822385
# Ellipsoid semi-axis:  211.523349437486 211.52334943748602 98.28796071426973
# Rotation angle:  190.00797980144137
# Initial volume 1091801.8052561937  m3
# semi_axis1 205.1789985878515
# Ellissoid center: 495 545 1610.0735851158222
# Ellipsoid semi-axis:  205.17899858785148 205.1789985878515 96.08805044785345
# Rotation angle:  194.5344550805401
# Initial volume 1000838.1222902797  m3
# semi_axis1 200.30781793807546
# Ellissoid center: 495 545 1608.3965597981305
# Ellipsoid semi-axis:  200.30781793807543 200.30781793807546 94.41102513016176
# Rotation angle:  194.88626684901755
# Initial volume 935086.9855748464  m3
# semi_axis1 204.04790127916615
# Ellissoid center: 495 545 1609.939240830076
# Ellipsoid semi-axis:  204.04790127916613 204.04790127916615 95.95370616210721
# Rotation angle:  193.20108717570557
# Initial volume 982071.4354086469  m3
# semi_axis1 204.91635566538588
# Ellissoid center: 495 545 1609.9871620095537
# Ellipsoid semi-axis:  204.91635566538594 204.91635566538588 96.00162734158494
# Rotation angle:  194.5344550805401
# Initial volume 997136.9314743724  m3
# semi_axis1 205.1180124072713
# Ellissoid center: 495 545 1610.0535175080004
# Ellipsoid semi-axis:  205.11801240727124 205.1180124072713 96.06798284003162
# Rotation angle:  194.5344550805401
# Initial volume 999945.2446805536  m3
# semi_axis1 205.16483748201685
# Ellissoid center: 495 545 1610.0689253795424
# Ellipsoid semi-axis:  205.16483748201682 205.16483748201685 96.08339071157366
# Rotation angle:  194.5344550805401
# Initial volume 1000632.596895261  m3
# semi_axis1 205.15396461159145
# Ellissoid center: 495 545 1610.0653476427908
# Ellipsoid semi-axis:  205.15396461159142 205.15396461159145 96.07981297482206
# Rotation angle:  194.5344550805401
# Initial volume 1000474.2078835296  m3
#
# Saving output

# %% [markdown]
# ### TITAN2D

# %%
os.chdir("Titan2D")

f=open("./input.py","r+")
inp = f.readlines()
inp[4] = "    gis_map='../DEMs_PDC_Benchmark/bend_arc.asc',\n"
inp[23] = "     influx=10.0,\n"
inp[24] = "    start_time=0.0,\n"
inp[25] = "   end_time=100.0,\n"
inp[26] = "    center=[500.0, 550.0],\n"
f.seek(0)
f.writelines(inp)
f.truncate()
f.close()

subprocess.run("./titan -nt 4 input.py",shell=True,stdout=subprocess.DEVNULL)
# Out:
# CompletedProcess(args='./titan -nt 4 input.py', returncode=0)

# %%
height = []
os.chdir("vizout")
result = subprocess.run("ls -1 | sort | tail -n 1", capture_output=True, text=True,shell=True)
filename = result.stdout.strip()
with h5py.File(filename, 'r')  as h5f: # file will be closed when we exit from WITH scope
    connections = h5f.get("Mesh/Connections")
    points = h5f.get("Mesh/Points")
    height = h5f.get("Properties/PILE_HEIGHT")[:]
    centers = []
    for i in range(connections.shape[0]):
        midpoint = points[np.sort(connections[i,:])]
        out = np.mean(midpoint,axis=0)
        centers = np.append(centers,out,axis=0)
    centers = np.reshape(centers,(connections.shape[0],3))
height = np.ndarray.flatten(height)
df = {"X_CENTER": centers[:,0], 'Y_CENTER': centers[:,1], 'Z_CENTER': centers[:,2],'PILE_HEIGHT': height}
df = pd.DataFrame(df)
nonzero = df["PILE_HEIGHT"] > 0
flow = df[nonzero]
os.chdir("../..")
flow.to_csv("./titandata.csv")

# %%
vals = pd.read_csv("titandata.csv",skiprows=3, names=["x","y","z","thickness"])
points = list(zip(vals.x,vals.y))
values = vals.thickness.values
xRange = np.arange(vals.x.min(),vals.x.max()+res,res)
yRange = np.arange(vals.y.min(),vals.y.max()+res,res)
gridX,gridY = np.meshgrid(xRange, yRange)
gridPh = griddata(points, values, (gridX,gridY), method='linear')
gridPh = np.nan_to_num(gridPh, nan=-999999)
rasterCrs = rio.crs.CRS.from_epsg(4326)
transform = rio.transform.Affine.translation(gridX[0][0]-res/2, gridY[0][0]-res/2)*rio.transform.Affine.scale(res,res)
interpRaster = rio.open('Titan2D/titan_bend.asc',
                                'w',
                                driver='AAIGrid',
                                height=gridPh.shape[0],
                                width=gridPh.shape[1],
                                count=1,
                                dtype=gridPh.dtype,
                                crs=rasterCrs,
                                transform=transform,
                                nodata=-999999
                                )
interpRaster.write(gridPh,1)
interpRaster.close()

# %%
fig, (ax0, ax1, ax2) = plt.subplots(ncols=3, nrows=1,subplot_kw=dict(projection=ccrs.epsg(32628)), figsize = (9,6))

thickness0,maxval0 = victor.plot_benchmark(dem, "./VolcFlow/bend_output.grd", fig, ax0, coordinates, zoom=False)
ax0.set_title('VolcFlow', fontsize=16)

thickness1,maxval1 = victor.plot_benchmark(dem, "./Titan2D/titan_bend.asc", fig, ax1, coordinates, zoom=False)
ax1.set_title('TITAN2D', fontsize=16)

thickness2,maxval2 = victor.plot_benchmark(dem, "./IMEX_SfloW_2D/bend_arc_0010.asc", fig, ax2, coordinates, zoom=False)
ax2.set_title('IMEX_SfloW2D', fontsize=16)
# Out:
# Text(0.5, 1.0, 'IMEX_SfloW2D')
