# %% [markdown]
# ### Obstacle Benchmark
#
# This benchmark simulates a pyroclastic flow in a channel that includes a an obstacle partway through

# %%
import rioxarray as rxr
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.insert(0,"/home/jovyan/shared/Libraries")
import victor
import subprocess
import os

# %% [markdown]
# ### To choose between levels of flux, please specify

# %%
easting = 750
northing = 500
dem = "DEMs_PDC_Benchmark/obstacle_arc.asc"
raster = rxr.open_rasterio(dem)
raster = raster.sel({"band": 1})
xll, yll = float(raster.x.min()), float(raster.y.min())
coordinates = np.array([int(easting),int(northing)])
res = raster.rio.resolution()[0]

# %% [markdown]
# ## Volcflow
#
# ### An open source varient running on Octave

# %%
os.chdir("/home/jovyan/PDC Benchmark/VolcFlow")
f = open("toposcript.m","r+")
inp = f.readlines()
inp[0] = f"fid = fopen('../DEMs_PDC_Benchmark/obstacle_arc.grd');\n"
inp[24] = f"dtplot = 1;\n"
inp[25] = f"tmax = 100;\n"
inp[36] = f"V={1e6};\n"
inp[38] = f"r=5;\n"
inp[42] = "jh=100; ih=150;\n"
f.seek(0)
f.writelines(inp)
f.truncate()
f.close()

g = open("output_script.m","r+")
inp = g.readlines()
inp[0] = "fid = fopen('../DEMs_PDC_Benchmark/obstacle_arc.grd');\n"
inp[15] = "out=fopen('obstacle_output.grd','wb');\n"
g.seek(0)
g.writelines(inp)
g.truncate()
g.close()

subprocess.run("octave VF_run.m",shell=True,stderr=subprocess.DEVNULL)

os.chdir("..")

# %% [markdown]
# ### IMEX_SfloW_2D

# %%
os.chdir("/home/jovyan/PDC Benchmark/IMEX_SfloW_2D")

f=open("./IMEX_SfloW2D.inp","r+")
inp = f.readlines()
inp[1] =  'RUN_NAME="obstacle_arc",\n'
inp[2] =  f"""RESTART=F,\n"""
inp[3] =  f"""T_START=  0     ,\n"""
inp[4] =  f"""T_END=  100,\n"""
inp[5] =  f"""DT_OUTPUT=  10,\n"""
inp[13] = f"""X0={xll},\n"""
inp[14] = f""" Y0=  {yll}     ,\n"""
inp[15] = f" TOPOGRAPHY_FILE = '../{dem}' ,\n"
inp[16] = f""" COMP_CELLS_X=  300,\n"""
inp[17] = f""" COMP_CELLS_Y=  1000,	\n"""
inp[18] = f""" CELL_SIZE = 5.0D0    ,\n"""
inp[120] = f" X_SOURCE = {easting} ,\n"
inp[121] = f" Y_SOURCE = {northing} ,\n"
inp[122] = " H_SOURCE = 2.5D0 ,\n"
inp[123] = " R_SOURCE = 10.0D0 ,\n"
inp[124] = " VEL_SOURCE = 65.0D0 ,\n"
inp[125] = " T_SOURCE = 350.0D0 , \n"
inp[126] = "ALPHAS_SOURCE = 0.02D0 ,\n "
f.seek(0)
f.writelines(inp)
f.truncate()
f.close()

p = subprocess.Popen(['./IMEX_SfloW2D'], stdin=subprocess.PIPE, shell=True)
os.chdir("..")

# %% [markdown]
# ### TITAN2D

# %%
os.chdir("/home/jovyan/PDC Benchmark/Titan2D")

f=open("./input.py","r+")
inp = f.readlines()
inp[4] = "    gis_map='../DEMs_PDC_Benchmark/obstacle_arc.asc',\n"
inp[23] = "     influx=10.0,\n"
inp[24] = "    start_time=0.0,\n"
inp[25] = "   end_time=100.0,\n"
inp[26] = "    center=[750.0, 500.0],\n"
f.seek(0)
f.writelines(inp)
f.truncate()
f.close()

subprocess.run("./titan -nt 4 input.py",shell=True,stderr=subprocess.DEVNULL)

# %%
f=open("./conv2.R","r+")
inp = f.readlines()
inp[19] = 'mydir="/home/jovyan/PDC Benchmark/Titan2D"\n'
inp[21] = 'convert<-function(filename="obstacle.asc",calcCellsize=TRUE,cellsize=5,NODATA_value="-9999")'
f.seek(0)
f.writelines(inp)
f.truncate()
f.close()

# !Rscript conv2.R

# %%
os.chdir("/home/jovyan/PDC Benchmark")

volcflow = rxr.open_rasterio("VolcFlow/obstacle_output.grd",masked=True)
a = volcflow.max()
titan2d = rxr.open_rasterio("Titan2D/obstacle.asc",masked=True)
b = titan2d.max()
imex = rxr.open_rasterio("IMEX_SfloW_2D/obstacle_arc_max.asc",masked=True)
c = imex.max()
scale = max([a,b,c])

fig, (ax0, ax1, ax2) = plt.subplots(ncols=3, nrows=1,sharey=True)

victor.plot_flow(dem, "./VolcFlow/obstacle_output.grd", axes=ax0, coords=coordinates,zoom=False,title='Volcflow',scale=scale)
victor.plot_flow(dem, "./Titan2D/obstacle.asc", axes=ax1, coords=coordinates, zoom=False,title='Titan2D',scale=scale)
victor.plot_flow(dem, "./IMEX_SfloW_2D/obstacle_arc_max.asc", axes=ax2, coords=coordinates, zoom=False,title='IMEX_SfloW',scale=scale)
