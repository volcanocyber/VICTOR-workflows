# %% [markdown]
# ## Downflow
# #### A workflow for Downflow, a model for calculating a lava flow's steepest descent
#
# To run this code, we require a few simple parameters.
#
# First, input the DEM you would like to use.

# %%
from PIL import Image
from IPython.display import display

# %%
dem =

# %% [markdown]
# Next, please enter the total number of simulations, as well as the number of steps in each simulation.

# %%
sims = 5000

max_steps = 1e8

# %% [markdown]
# Finally, please enter the row and column number of the DEM as a starting point, the max flow length (in meters), and the size of each cell (also in meters).

# %%
row_init = 

col_init = 

max_length = 

cellsize =

# %%
f=open("downflow.py","r+")
inp = f.readlines()
inp[4] = f"""A = \"{dem}\"\n"""
inp[5] = f"""xr = {sims}\n"""
inp[6] = f"""pathsteps = {max_steps}\n"""
inp[7] = f"""rinit = {row_init}\n"""
inp[8] = f"""cinit = {col_init}\n"""
inp[9] = f"""length = {max_length}\n"""
inp[10]= f"""cellsize = {cellsize}\n"""

f.seek(0)
f.writelines(inp)
f.truncate()
f.close()

# %%
# !python downflow.py

# %%
img = Image.open('downflow.png')
display(img)
