# %% [markdown]
# # Using Leafmap and Earthaccess to Explore OPERA Products

# %% [markdown]
# The Leafmap library provides a suite of tools for interactive mapping and visualization in Jupyter Notebooks Leafmap version 0.30.0 and and later offer tools specifically for accessing NASA Earthdata by building on the newly developed NASA Earthaccess library. Earthaccess provides streamlined access to NASA Earthdata and simplifies the authentication and querying process over previously developed approaches.This notebook is designed to leverage tools within Earthaccess and Leafmap to facility easier access and vizualization of OPERA data products for a user-specified area of interest (AOI).

# %% [markdown]
# ## Import Libraries

# %%
import earthaccess
import leafmap
import pandas as pd
import geopandas as gpd
from shapely import box
from datetime import datetime
from pyproj import Transformer
import rioxarray as rxr
import matplotlib.pyplot as plt
from localtileserver import get_leaflet_tile_layer, TileClient
import numpy as np

# %% [markdown]
# ## Authentication
# A [NASA Earthdata Login](https://urs.earthdata.nasa.gov/) account is required to download the data used in this tutorial. You can create an account at the link provided. After establishing an account, the code in the next cell will verify authentication. If this is your first time running the notebook, you will be prompted to enter your Earthdata login credentials, which will be saved in ~/.netrc.

# %%
leafmap.nasa_data_login()
# Out:
# Enter your Earthdata Login username:  samkrasnoff
# Enter your Earthdata password:  ········

# %% [markdown]
# ## Create an interactive Leaflet map to define an area of interest (AOI) OR enter existing volcano coordinates
# Leafmap provides the capability to create an interactive map in the Jupyter Notebook and to use the cursor to define an area of interest (AOI). When the user defines an AOI, the boundary is saved as an object. Give this a try in the next cell.

# %%
### Enter volcano coordinates here
lat = -7.54
# 7.54°S, 110.446°E
long = 110.45

# %%
m = leafmap.Map(center=[42,-100], zoom=4, basemap='Google Satellite')
m
# Out:
# Map(center=[42, -100], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %% [markdown]
# ### Below, the user can see their selected area of interest, and confirm/edit the bounds.

# %%
### This cell initializes the AOI for future use. If the user didn't define an AOI in the previous cell, the AOI defaults to an bounding box over Ridgecrest, California (USA)
if m.user_roi is not None:
    AOI = tuple(m.user_roi_bounds())
else:
    AOI = (long - .01, lat -.01, long + .01, lat + .01)
print(AOI)
# Out:
# (110.44, -7.55, 110.46000000000001, -7.53)

# %% [markdown]
# ## Specify a time constraint, from 2021 to present
#  Please use the format YYYY-MM-DD

# %%
start_date = "2022-12-01"

end_date = "2023-04-30"

# %% [markdown]
# ## Query Earthdata and return metadata for OPERA products within the AOI
# The `earthaccess` library makes it simple to quickly query NASA's Common Metadata Repository (CMR) and return the associated metadata as a Geodataframe. `Leafmap` has recently added functionality that builds on `earthaccess` to enable interactive viewing of this data.
# In the next cell, the user should specify which OPERA product and the date range of interest. The AOI defined previously is used as the boundary in the query.

# %% [markdown]
# ### View OPERA Product Shortnames

# %% [markdown]
# The `leafmap.nasa_data_search()` function returns a Geodataframe containing the metadata for all granules which intersect the AOI from the specified time range. Let's look at the first five granules.

# %% [markdown]
# ### Query the OPERA DIST-ALERT-HLS dataset for the AOI

# %%
dist_results, dist_gdf = leafmap.nasa_data_search(
    short_name='OPERA_L3_DIST-ALERT-HLS_V1',
    cloud_hosted=True,
    bounding_box= AOI,
    temporal=(start_date,end_date),
    count=-1,  # use -1 to return all datasets
    return_gdf=True,
)

# %% [markdown]
# ### See the available DIST-ALERT-HLS layers

# %%
dist_results[0]
# Out:
# Collection: {'ShortName': 'OPERA_L3_DIST-ALERT-HLS_V1', 'Version': '1'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'GPolygons': [{'Boundary': {'Points': [{'Longitude': 110.65797167, 'Latitude': -8.23035327}, {'Longitude': 110.86883392, 'Latitude': -7.23726581}, {'Longitude': 110.09383235, 'Latitude': -7.23638323}, {'Longitude': 110.09171089, 'Latitude': -8.22947213}, {'Longitude': 110.65797167, 'Latitude': -8.23035327}]}}]}}}
# Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2023-01-03T02:48:34.863026Z', 'EndingDateTime': '2023-01-03T02:48:58.787928Z'}}
# Size(MB): 0
# Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/OPERA_L3_DIST-ALERT-HLS_V1/OPERA_L3_DIST-ALERT-HLS_T49MDM_20230103T024834Z_20231222T051311Z_L9_30_v1/OPERA_L3_DIST-ALERT-HLS_T49MDM_20230103T024834Z_20231222T051311Z_L9_30_v1_VEG-DIST-STATUS.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/OPERA_L3_DIST-ALERT-HLS_V1/OPERA_L3_DIST-ALERT-HLS_T49MDM_20230103T024834Z_20231222T051311Z_L9_30_v1/OPERA_L3_DIST-ALERT-HLS_T49MDM_20230103T024834Z_20231222T051311Z_L9_30_v1_VEG-IND.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/OPERA_L3_DIST-ALERT-HLS_V1/OPERA_L3_DIST-ALERT-HLS_T49MDM_20230103T024834Z_20231222T051311Z_L9_30_v1/OPERA_L3_DIST-ALERT-HLS_T49MDM_20230103T024834Z_20231222T051311Z_L9_30_v1_VEG-ANOM.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/OPERA_L3_DIST-ALERT-HLS_V1/OPERA_L3_DIST-ALERT-HLS_T49MDM_20230103T024834Z_20231222T051311Z_L9_30_v1/OPERA_L3_DIST-ALERT-HLS_T49MDM_20230103T024834Z_20231222T051311Z_L9_30_v1_VEG-HIST.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/OPERA_L3_DIST-ALERT-HLS_V1/OPERA_L3_DIST-ALERT-HLS_T49MDM_20230103T024834Z_20231222T051311Z_L9_30_v1/OPERA_L3_DIST-ALERT-HLS_T49MDM_20230103T024834Z_20231222T051311Z_L9_30_v1_VEG-ANOM-MAX.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/OPERA_L3_DIST-ALERT-HLS_V1/OPERA_L3_DIST-ALERT-HLS_T49MDM_20230103T024834Z_20231222T051311Z_L9_30_v1/OPERA_L3_DIST-ALERT-HLS_T49MDM_20230103T024834Z_20231222T051311Z_L9_30_v1_VEG-DIST-CONF.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/OPERA_L3_DIST-ALERT-HLS_V1/OPERA_L3_DIST-ALERT-HLS_T49MDM_20230103T024834Z_20231222T051311Z_L9_30_v1/OPERA_L3_DIST-ALERT-HLS_T49MDM_20230103T024834Z_20231222T051311Z_L9_30_v1_VEG-DIST-DATE.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/OPERA_L3_DIST-ALERT-HLS_V1/OPERA_L3_DIST-ALERT-HLS_T49MDM_20230103T024834Z_20231222T051311Z_L9_30_v1/OPERA_L3_DIST-ALERT-HLS_T49MDM_20230103T024834Z_20231222T051311Z_L9_30_v1_VEG-DIST-COUNT.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/OPERA_L3_DIST-ALERT-HLS_V1/OPERA_L3_DIST-ALERT-HLS_T49MDM_20230103T024834Z_20231222T051311Z_L9_30_v1/OPERA_L3_DIST-ALERT-HLS_T49MDM_20230103T024834Z_20231222T051311Z_L9_30_v1_VEG-DIST-DUR.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/OPERA_L3_DIST-ALERT-HLS_V1/OPERA_L3_DIST-ALERT-HLS_T49MDM_20230103T024834Z_20231222T051311Z_L9_30_v1/OPERA_L3_DIST-ALERT-HLS_T49MDM_20230103T024834Z_20231222T051311Z_L9_30_v1_VEG-LAST-DATE.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/OPERA_L3_DIST-ALERT-HLS_V1/OPERA_L3_DIST-ALERT-HLS_T49MDM_20230103T024834Z_20231222T051311Z_L9_30_v1/OPERA_L3_DIST-ALERT-HLS_T49MDM_20230103T024834Z_20231222T051311Z_L9_30_v1_GEN-DIST-STATUS.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/OPERA_L3_DIST-ALERT-HLS_V1/OPERA_L3_DIST-ALERT-HLS_T49MDM_20230103T024834Z_20231222T051311Z_L9_30_v1/OPERA_L3_DIST-ALERT-HLS_T49MDM_20230103T024834Z_20231222T051311Z_L9_30_v1_GEN-ANOM.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/OPERA_L3_DIST-ALERT-HLS_V1/OPERA_L3_DIST-ALERT-HLS_T49MDM_20230103T024834Z_20231222T051311Z_L9_30_v1/OPERA_L3_DIST-ALERT-HLS_T49MDM_20230103T024834Z_20231222T051311Z_L9_30_v1_GEN-ANOM-MAX.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/OPERA_L3_DIST-ALERT-HLS_V1/OPERA_L3_DIST-ALERT-HLS_T49MDM_20230103T024834Z_20231222T051311Z_L9_30_v1/OPERA_L3_DIST-ALERT-HLS_T49MDM_20230103T024834Z_20231222T051311Z_L9_30_v1_GEN-DIST-CONF.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/OPERA_L3_DIST-ALERT-HLS_V1/OPERA_L3_DIST-ALERT-HLS_T49MDM_20230103T024834Z_20231222T051311Z_L9_30_v1/OPERA_L3_DIST-ALERT-HLS_T49MDM_20230103T024834Z_20231222T051311Z_L9_30_v1_GEN-DIST-DATE.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/OPERA_L3_DIST-ALERT-HLS_V1/OPERA_L3_DIST-ALERT-HLS_T49MDM_20230103T024834Z_2023 ...

# %% [markdown]
# ### View the DIST-ALERT-HLS metadata and footprints

# %%
dist_gdf.head()
# Out:
#    size concept-type           concept-id  revision-id  \
# 0     0      granule  G2865212475-LPCLOUD            1
# 1     0      granule  G3215848797-LPCLOUD            1
# 2     0      granule  G3216962895-LPCLOUD            1
# 3     0      granule  G3217816888-LPCLOUD            1
# 4     0      granule  G3221244097-LPCLOUD            1
#
#                                            native-id collection-concept-id  \
# 0  OPERA_L3_DIST-ALERT-HLS_T49MDM_20230103T024834...   C2746980408-LPCLOUD
# 1  OPERA_L3_DIST-ALERT-HLS_T49MDM_20230108T024101...   C2746980408-LPCLOUD
# 2  OPERA_L3_DIST-ALERT-HLS_T49MDM_20230111T024829...   C2746980408-LPCLOUD
# 3  OPERA_L3_DIST-ALERT-HLS_T49MDM_20230113T024049...   C2746980408-LPCLOUD
# 4  OPERA_L3_DIST-ALERT-HLS_T49MDM_20230119T024826...   C2746980408-LPCLOUD
#
#   provider-id                             format             revision-date  \
# 0     LPCLOUD  application/vnd.nasa.cmr.umm+json  2024-02-14T14:27:09.359Z
# 1     LPCLOUD  application/vnd.nasa.cmr.umm+json  2024-08-28T01:08:07.457Z
# 2     LPCLOUD  application/vnd.nasa.cmr.umm+json  2024-08-28T21:33:09.143Z
# 3     LPCLOUD  application/vnd.nasa.cmr.umm+json  2024-08-29T12:49:07.434Z
# 4     LPCLOUD  application/vnd.nasa.cmr.umm+json  2024-08-31T04:54:07.056Z
#
#              BeginningDateTime  ...  \
# 0  2023-01-03T02:48:34.863026Z  ...
# 1  2023-01-08T03:00:05.794690Z  ...
# 2  2023-01-11T02:48:29.854354Z  ...
# 3  2023-01-13T03:00:02.563470Z  ...
# 4  2023-01-19T02:48:26.094399Z  ...
#
#                                        ProviderDates  \
# 0  [{'Date': '2023-12-22T05:13:11.181850Z', 'Type...
# 1  [{'Date': '2023-12-22T05:14:07.404855Z', 'Type...
# 2  [{'Date': '2023-12-22T05:14:26.387602Z', 'Type...
# 3  [{'Date': '2023-12-22T05:15:21.144841Z', 'Type...
# 4  [{'Date': '2023-12-22T05:15:58.602774Z', 'Type...
#
#                     ShortName  \
# 0  OPERA_L3_DIST-ALERT-HLS_V1
# 1  OPERA_L3_DIST-ALERT-HLS_V1
# 2  OPERA_L3_DIST-ALERT-HLS_V1
# 3  OPERA_L3_DIST-ALERT-HLS_V1
# 4  OPERA_L3_DIST-ALERT-HLS_V1
#
#                                          RelatedUrls CloudCover DayNightFlag  \
# 0  [{'URL': 'https://data.lpdaac.earthdatacloud.n...        100          Day
# 1  [{'URL': 'https://data.lpdaac.earthdatacloud.n...         87          Day
# 2  [{'URL': 'https://data.lpdaac.earthdatacloud.n...         99          Day
# 3  [{'URL': 'https://data.lpdaac.earthdatacloud.n...         62          Day
# 4  [{'URL': 'https://data.lpdaac.earthdatacloud.n...         92          Day
#
#             ProductionDateTime  \
# 0  2023-12-22T05:13:11.181850Z
# 1  2023-12-22T05:14:07.404855Z
# 2  2023-12-22T05:14:26.387602Z
# 3  2023-12-22T05:15:21.144841Z
# 4  2023-12-22T05:15:58.602774Z
#
#                                            Platforms  \
# 0  [{'ShortName': 'LANDSAT-9', 'Instruments': [{'...
# 1  [{'ShortName': 'Sentinel-2A', 'Instruments': [...
# 2  [{'ShortName': 'LANDSAT-8', 'Instruments': [{'...
# 3  [{'ShortName': 'Sentinel-2B', 'Instruments': [...
# 4  [{'ShortName': 'LANDSAT-9', 'Instruments': [{'...
#
#                                                  URL   Name  \
# 0  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.6  UMM-G
# 1  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.6  UMM-G
# 2  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.6  UMM-G
# 3  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.6  UMM-G
# 4  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.6  UMM-G
#
#                                             geometry
# 0  POLYGON ((110.65797 -8.23035, 110.86883 -7.237...
# 1  POLYGON ((111.08862 -8.23049, 111.08841 -7.237...
# 2  POLYGON ((110.66287 -8.23036, 110.87373 -7.237...
# 3  POLYGON ((111.08834 -8.23049, 111.08841 -7.237...
# 4  POLYGON ((110.68657 -8.23038, 110.89764 -7.237...
#
# [5 rows x 24 columns]

# %%
### Plot the location of the tiles 
dist_gdf.explore(fill=False)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b623979e47284b4976de5c73e8250783 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b623979e47284b4976de5c73e8250783&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b623979e47284b4976de5c73e8250783 = L.map(
#                 &quot;map_b623979e47284b4976de5c73e8250783&quot;,
#                 {
#                     center: [-7.733436190000001, 110.59016412],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_b623979e47284b4976de5c73e8250783);
#
#
#
#
#
#             var tile_layer_89a118f1680064d9917bef708d9a72c8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_89a118f1680064d9917bef708d9a72c8.addTo(map_b623979e47284b4976de5c73e8250783);
#
#
#             map_b623979e47284b4976de5c73e8250783.fitBounds(
#                 [[-8.23048915, 110.09171089], [-7.23638323, 111.08861735]],
#                 {}
#             );
#
#
#         function geo_json_1ba7b50d02bb0c8296c6cd113a3dd973_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_1ba7b50d02bb0c8296c6cd113a3dd973_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_1ba7b50d02bb0c8296c6cd113a3dd973_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_1ba7b50d02bb0c8296c6cd113a3dd973_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_1ba7b50d02bb0c8296c6cd113a3dd973_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_1ba7b50d02bb0c8296c6cd113a3dd973.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_1ba7b50d02bb0c8296c6cd113a3dd973_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_1ba7b50d02bb0c8296c6cd113a3dd973 = L.geoJson(null, {
#                 onEachFeature: geo_json_1ba7b50d02bb0c8296c6cd113a3dd973_onEachFeature,
#
#                 style: geo_json_1ba7b50d02bb0c8296c6cd113a3dd973_styler,
#                 pointToLayer: geo_json_1ba7b50d02bb0c8296c6cd113a3dd973_pointToLayer,
#                 fill: false,
#         });
#
#         function geo_json_1ba7b50d02bb0c8296c6cd113a3dd973_add (data) {
#             geo_json_1ba7b50d02bb0c8296c6cd113a3dd973
#                 .addData(data);
#         }
#             geo_json_1ba7b50d02bb0c8296c6cd113a3dd973_add({&quot;bbox&quot;: [110.09171089, -8.23048915, 111.08861735, -7.23638323], &quot;features&quot;: [{&quot;bbox&quot;: [110.09171089, -8.23035327, 110.86883392, -7.23638323], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[110.65797167, -8.23035327], [110.86883392, -7.23726581], [110.09383235, -7.23638323], [110.09171089, -8.22947213], [110.65797167, -8.23035327]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;AdditionalAttributes&quot;: [{&quot;Name&quot;: &quot;Input_DIST-ALERT_granule&quot;, &quot;Values&quot;: [&quot;first&quot;]}, {&quot;Name&quot;: &quot;BaselineCalendarWindow&quot;, &quot;Values&quot;: [&quot;+/- 15 days&quot;]}, {&quot;Name&quot;: &quot;BaselineYearWindow&quot;, &qu

# %% [markdown]
# ## Download data with leafmap
# *<font color='red'>Important note: As of Jan. 2024, OPERA RTC and CSLC may not be accessible using the earthaccess library due to additional athentication measures required by ASF DAAC. This will likely be resolved soon, but currently the notebook should be used only to access OPERA products distributed by LP DAAC and PO.DAAC. For additional details regarding the current status of using earthaccess to access data from ASF DAAC, see the linked Github Issue ([#439](https://github.com/nsidc/earthaccess/issues/439#issuecomment-1915518987)).</font>*
#
# Let's download some data from one of our above queries. In the cell below we specify data from the DIST query, but feel free to modify to any of the others above. *Note: We also filter to include the layer we would like to from the product we would like. So modify this step accordingly if a different product is chosen.

# %% [markdown]
# ### Create a subdirectory
# This will be where the files are downloaded. It will be a subdirectory inside of a directory called `data`, and the directory name will be the datetime that it was created.

# %%
import os
from datetime import datetime

def create_data_directory():
    # Get the current date and time
    current_datetime = datetime.now().strftime("%m_%d_%Y_%H_%M_%S")
    volcano = "iceland"
    # Define the base directory
    base_directory = "data"

    # Create the full path for the new directory
    new_directory_path = os.path.join(base_directory, f"data_{volcano}")

    # Create the new directory
    os.makedirs(new_directory_path, exist_ok=True)
    print(f"Directory '{new_directory_path}' created successfully.")

    return new_directory_path, volcano

directory_path, volcano = create_data_directory()
# Out:
# Directory 'data/data_iceland' created successfully.

# %% [markdown]
# ### Download the data
# The below will download the data to your newly created subdirectory. Look on your file system for a directory `/data/datetime/` where `datetime` is the date and time the directory was created.

# %%
dist_data = leafmap.nasa_data_download(dist_results, out_dir=directory_path)     # Downloads the first 5 granules. Remove [:5] to download all granules or modify to keep as many as you like
# Out:
# QUEUEING TASKS | :   0%|          | 0/608 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/608 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/608 [00:00<?, ?it/s]

# %% [markdown]
# ## View the files using Leafmap

# %% [markdown]
# ### Load in images from data folder
# We load in data from only band 1 below. If you'd like load data from a different band change the `B01` to suit your needs.

# %%
import os

# Get the current directory
current_directory = os.getcwd()

# Construct the path to the data directory
data_directory = os.path.join(current_directory, directory_path)

# Create a list of file paths and a list of corresponding dates
images = [os.path.join(data_directory, filename) for filename in os.listdir(data_directory) if os.path.isfile(os.path.join(data_directory, filename)) and 'VEG-ANOM-MAX.tif' in filename]

tiling = [w[75+len(volcano):75+len(volcano)+6] for w in images]
tiles = []
for x in tiling:
    if x not in tiles:
        tiles.append(x)
granules = dict()
for tile in tiles:
    granules[tile] = []

for count, image in enumerate(images):
    if 'VEG-ANOM-MAX' in image:
        granules[tiling[count]].append(image)

for key in granules:
    granules[key].sort(key=lambda x: x[88+len(volcano):88+len(volcano)+8])

# %% [markdown]
# ### Select the best granule for your data

# %%
i=1
for key in granules:
    dem = rxr.open_rasterio(granules[key][0], masked=True)
    ax1 = plt.subplot(len(granules),1, i)
    ax1.set_aspect('equal')
    dem.plot()
    plt.title(key)
    plt.show()
    i += 1

# %%
granule = "T27VVL"

# %% [markdown]
# ## Select area of interest within granule

# %%
m = leafmap.Map()
m.add_raster(granules[granule][0])
m
# Out:
# Map(center=[63.52754349999999, -21.923382], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_i…

# %%
dem = rxr.open_rasterio(granules[granule][0],masked=True)
project = dem.rio.crs.to_epsg()
transformer = Transformer.from_crs("EPSG:4326",f"EPSG:{project}")
x = m.user_roi_bounds()
ll = transformer.transform(x[1],x[0])
ur = transformer.transform(x[3],x[2])
dem = dem.sel(x=slice(ll[0],ur[0]))
dem = dem.sel(y=slice(ur[1],ll[1]))
dem.plot()
plt.title("Cropped granule")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 5
#       3 transformer = Transformer.from_crs("EPSG:4326",f"EPSG:{project}")
#       4 x = m.user_roi_bounds()
# ----> 5 ll = transformer.transform(x[1],x[0])
#       6 ur = transformer.transform(x[3],x[2])
#       7 dem = dem.sel(x=slice(ll[0],ur[0]))
#
# TypeError: 'NoneType' object is not subscriptable

# %%
granules[granule]

# %%
from osgeo import gdal
import subprocess
dataset = []
for tif in granules[granule]:
    tif1, tif2 = tif[0:51+len(volcano)], tif[51+len(volcano):]
    window = (ll[0],ur[1],ur[0],ll[1])
    window = (x[0],x[3],x[2],x[1])
    new_name = ''.join((tif1, "cropped_",tif2))
    dataset.append(new_name)
    subprocess.run(f"gdal_translate -projwin {ll[0]}, {ur[1]}, {ur[0]}, {ll[1]} -f GTiff {granules[granule][0]} {new_name}",shell=True)

# %% [markdown]
# ### Create a timelapse (.gif) of the images over this region

# %%
leafmap.create_timelapse(
    dataset,
    out_gif='dist-anom.gif',
    fps=1,
    progress_bar_color='blue',
    add_text=False,
    # text_xy=('3%', '3%'),
    # text_sequence=[str(date) for date in granules[granule][88+len(volcano):88+len(volcano)+8]],
    font_size=20,
    font_color='red',
    mp4=False,
    reduce_size=False,
)

# %%
leafmap.show_image('dist-anom.gif',height="450px", width="450px")

# %% [markdown]
# ## View OPERA data in Leafmap GUI

# %%
m = leafmap.Map()
m.add("nasa_earth_data")
m

# %% [markdown]
# ### Download the Displayed Footprints

# %% [markdown]
# ## Make a timeslider to visualize granules
# Make an interactive timeslide to cycle through the images. This isn't the perfect solution, as the granules in our list do not have identical footprints.

# %%
m = leafmap.Map()
m.add_time_slider(
    dataset,
    time_interval=1,
    position='bottomright',
    zoom_to_layer=True,
)
m

# %%
mean = []
percentile_75 = []
for timestamp in granules[granule]:
    snapshot = rxr.open_rasterio(timestamp,masked=True)
    mean.append(snapshot.mean())
    flattened = snapshot.values.flatten()
    flattened = flattened[~np.isnan(flattened)]
    percentile_75.append(np.percentile(flattened,95))
plt.plot(mean)
plt.plot(percentile_75)

# for i in range(4):
#     ax1 = plt.subplot(2, 2, i+1)
#     altered_dem = dem.where(dem > vals[i])
#     altered_dem.plot()
#     plt.title('')
plt.show()
